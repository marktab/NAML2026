# %% [markdown]
# # Demo 2 — Maritime Gray-Zone Escalation Analysis Sandbox
# ## Red / Blue / White Cell Play
#
# **OODA Phase: Orient / Decide / Act**
#
# **Purpose:** Simulate a multi-turn gray-zone maritime encounter where Red, Blue, and White cell agents play against each other. Track escalation, strategic messaging, legal compliance, and operational objectives using quantified scoring dimensions inspired by the NATO STO-MP-SAS-192 card-based wargame approach.
#
# **Audience:** Warfighters, operational planners, strategists, and JAG officers.
# **Primary outcome:** A scored game log showing the interplay of escalation dynamics, legal constraints, and information warfare — consumable by Demo 5 (AAR) for live after-action review.
#
# > **Responsible AI & Scope Statement:** This research explores human-AI collaboration and explainable decision-support in fully synthetic, abstract environments. All scenarios, agents, and data are artificially generated. No real-world operational data, contingency plans, systems, or intelligence are used or represented. The prototype is intended exclusively for research, educational, and experimental purposes and does not constitute an operational model, validated planning tool, or source of decision authority.

# %% [markdown]
# ## What It Illustrates (Multi-Agent)
#
# | Agent | Role | Unique Contribution |
# |-------|------|---------------------|
# | **Blue Planner** | Selects actions from a defined menu; scores across 5 dimensions | Balances competing equities each turn |
# | **Red Team** | Selects provocations; explains adversary reasoning transparently | Transparent adversary thought process |
# | **White Cell / Umpire** | Adjudicates outcomes; updates escalation index; announces thresholds | Published rule set, visible to audience |
# | **Legal / ROE** | Constrains Blue's actions by current ROE posture + escalation level | Not in NATO precedent — novel JAG integration |
# | **Strategic Communications** | Drafts Blue public statements; predicts adversary media response | Info-warfare dimension rarely modeled |
# | **Explainability** | Produces transparent reasoning traces, bias checks, and scope compliance verification | Required by Responsible AI — ensures auditability |
#
# **Success criteria:** Over 4+ turns, escalation index rises and falls in response to Red provocations and Blue decisions. The Legal agent visibly constrains actions. StratComm messages create second-order effects. The Explainability Agent produces a transparent reasoning trace each turn. The game log is a valid input to Demo 5.

# %% [markdown]
# ## Demo Script (Presenter Guide)
#
# 1. **Intro (1 min):** "Demo 1 showed Observe/Orient. Now we cross into Decide/Act — with an adversary playing back."
# 2. **Show scoring (30 sec):** Walk through the 5 scoring dimensions and escalation ladder. "Every action has explicit tradeoffs."
# 3. **Turn 1 (2 min):** Red provokes, Legal constrains Blue's options, Blue responds, White adjudicates. "Watch the escalation index."
# 4. **Turns 2–4 (4 min):** Escalation builds. "Notice StratComm creating second-order effects, and Legal shutting down options as escalation rises."
# 5. **Human-in-the-Loop (2 min):** Override Blue's action as the commander. "The agents adapt."
# 6. **Close (1 min):** "This game log feeds directly into Demo 5 for live AAR."

# %% [markdown]
# ## Setup
#
# ### Azure Technologies Used
#
# This demo relies on several Azure services working together:
#
# | Azure Service | What It Does | Why We Use It Here |
# |---|---|---|
# | **[Azure AI Foundry](https://learn.microsoft.com/azure/ai-foundry/what-is-azure-ai-foundry)** | A unified platform for building, evaluating, and deploying generative AI applications. It provides access to a catalog of foundation models (e.g., GPT-4o, Phi, Llama) and tools for prompt engineering, fine-tuning, and evaluation. | Hosts the large language model (LLM) that powers every agent in this wargame. We call the model via its inference endpoint. |
# | **[Azure AI Model Inference API](https://learn.microsoft.com/azure/ai-foundry/model-inference/overview)** | A common REST/SDK interface that lets you call any model in the Azure AI catalog using the same code, regardless of provider (OpenAI, Meta, Microsoft, Mistral, etc.). | The `AzureAIChatCompletionClient` from AutoGen's `autogen-ext[azure]` package wraps this API so each agent can send chat-completion requests without model-specific code. |
# | **[Azure Key Vault](https://learn.microsoft.com/azure/key-vault/general/overview)** | A cloud service for securely storing and accessing secrets such as API keys, passwords, and certificates. Applications retrieve secrets at runtime instead of hard-coding them in source files. | Stores the `AZURE_INFERENCE_CREDENTIAL` (API key) so it never appears in notebooks or version control. The shared `common/config.py` module retrieves secrets from Key Vault using `DefaultAzureCredential`. |
#
# ### Environment Variables
#
# Before running this notebook, two environment variables must be set (typically loaded from a `.env` file or injected by your compute environment):
#
# | Variable | Description |
# |---|---|
# | `AZURE_INFERENCE_ENDPOINT` | The URL of your Azure AI Foundry model deployment (e.g., `https://<your-resource>.services.ai.azure.com/models`) |
# | `AZURE_INFERENCE_CREDENTIAL` | The API key (or token) that authenticates requests to the endpoint |
#
# > **Tip for newcomers:** You can create a free Azure account at [azure.microsoft.com/free](https://azure.microsoft.com/free) and deploy a model through the [Azure AI Foundry portal](https://ai.azure.com). For a step-by-step walkthrough, see [Quickstart: Get started with Azure AI Foundry](https://learn.microsoft.com/azure/ai-foundry/quickstarts/get-started-code).
#
# Requires AutoGen 0.7.5 (`autogen-agentchat`, `autogen-ext[azure]`) and the Azure AI Foundry inference environment variables described above.

# %%
# Uncomment to install dependencies
# %pip install -U "autogen-agentchat==0.7.5" "autogen-ext[azure]==0.7.5" python-dotenv

# %%
# ═══════════════════════════════════════════════════════════════
# NAML 2026 BOOTSTRAP v2 — Survives dead AML mounts (Errno 107)
# ═══════════════════════════════════════════════════════════════

import os
import sys

def _safe_stat(path: str) -> bool:
    try:
        os.stat(path)
        return True
    except OSError:
        return False

def _prune_dead_sys_path():
    kept = []
    removed = []
    for p in list(sys.path):
        if not p:
            kept.append(p)
            continue
        if _safe_stat(p):
            kept.append(p)
        else:
            removed.append(p)
    sys.path[:] = kept
    print(f"✓ Pruned sys.path. Removed {len(removed)} dead entries.")
    return removed

def _safe_listdir(path: str):
    try:
        return os.listdir(path)
    except OSError:
        return None

def _find_repo_root(marker_dir: str = "common", start_candidates=None, max_up: int = 6):
    """
    Find a repo root by looking for a marker directory (e.g., 'common').
    Avoids Path.exists()/stat on dead mounts by only using listdir on traversable dirs.
    """
    if start_candidates is None:
        start_candidates = []

    # Candidate starting points:
    #  - current working directory (may be dead)
    #  - directory of the notebook file if available via env (sometimes set)
    #  - user home (often stable)
    candidates = [os.getcwd()] + start_candidates + [os.path.expanduser("~")]

    checked = set()
    for base in candidates:
        cur = base
        for _ in range(max_up + 1):
            if cur in checked:
                break
            checked.add(cur)

            entries = _safe_listdir(cur)
            if entries is not None and marker_dir in entries:
                return cur  # found repo root

            parent = os.path.dirname(cur)
            if parent == cur:
                break
            cur = parent

    return None

# 1) prune dead sys.path entries
_prune_dead_sys_path()

# 2) find a safe repo root by locating the 'common/' folder
repo_root = _find_repo_root(marker_dir="common", start_candidates=[])

if repo_root:
    sys.path.insert(0, repo_root)
    print(f"✓ Repo root added: {repo_root}")
else:
    print("✗ Could not find repo root safely (mount may be disconnected).")
    print("  Fix: restart kernel/compute, or run from a local (non-/mnt) working copy.")

print("✓ Bootstrap complete.")
# Out:
# ✓ Pruned sys.path. Removed 2 dead entries.
# ✓ Repo root added: /mnt/batch/tasks/shared/LS_root/mounts/clusters/mark1/code/Users/matabl
# ✓ Bootstrap complete.

# %% [markdown]
# ## Imports
#
# ### Key Libraries and Azure SDKs
#
# | Package | Purpose | Learn More |
# |---|---|---|
# | **[AutoGen](https://microsoft.github.io/autogen/)** (`autogen-agentchat`) | Microsoft's open-source framework for building multi-agent AI applications. Agents coordinate via structured conversations — each with its own system prompt, role, and capabilities. | [AutoGen documentation](https://microsoft.github.io/autogen/stable/) |
# | **`autogen-ext[azure]`** | AutoGen extension providing `AzureAIChatCompletionClient`, which connects AutoGen agents to models hosted on Azure AI Foundry via the [Azure AI Model Inference API](https://learn.microsoft.com/azure/ai-foundry/model-inference/overview). | [AutoGen Azure extension](https://microsoft.github.io/autogen/stable/reference/python/autogen_ext.models.azure.html) |
# | **`azure-core`** | The foundational Azure SDK library for Python. Provides shared classes like `AzureKeyCredential` used to authenticate every Azure service call. | [azure-core on PyPI](https://pypi.org/project/azure-core/) |
# | **`azure-identity`** | Implements authentication methods including `DefaultAzureCredential`, which automatically selects the best credential (managed identity, CLI login, environment variables) for your environment. | [Azure Identity client library](https://learn.microsoft.com/python/api/overview/azure/identity-readme) |
# | **`azure-keyvault-secrets`** | Client library for reading secrets from Azure Key Vault. Used by `common/config.py` to load API keys at runtime. | [Key Vault secrets client library](https://learn.microsoft.com/python/api/overview/azure/keyvault-secrets-readme) |

# %%
import json
import os
import sys
from typing import Any, Dict, List, Optional

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_agentchat.ui import Console
from autogen_core.models import ModelFamily
from autogen_ext.models.azure import AzureAIChatCompletionClient
from azure.core.credentials import AzureKeyCredential

# ── Ensure common/ is importable ──────────────────────────────
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..", "..")))

from common.config import (
    ESCALATION_LADDER,
    get_escalation_level,
    ROE_POSTURES,
    ROEPosture,
    EscalationLevel,
    SCORING_DIMENSIONS,
    DEFAULT_TEMPERATURE,
    DEFAULT_TIMEOUT_S,
    DEMO2_LOG_FILENAME,
    ENV_AZURE_INFERENCE_ENDPOINT,
    ENV_AZURE_INFERENCE_CREDENTIAL,
    DEFAULT_MODEL,
 )
from common.ui import (
    render_turn_header,
    render_dashboard,
    render_threshold_alert,
    render_info_box,
    render_commander_box,
    render_summary_card,
 )
from common.logging import (
    log_info,
    log_success,
    log_section,
    log_step,
    log_metric,
    clear_logs,
 )

try:
    from dotenv import load_dotenv
    load_dotenv()
except ImportError:
    pass

log_success("Imports complete — common modules loaded.")
# Out:
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #2ea043; font-weight: 600;'>[SUCCESS]</span> <span style='color: #24292f;'>[2026-02-21 04:32:28]</span> <span style='color: #24292f;'>Imports complete — common modules loaded.</span></div>
# LogEntry(level='SUCCESS', message='Imports complete — common modules loaded.', timestamp='2026-02-21 04:32:28', extra={})

# %% [markdown]
# ## LLM Configuration
#
# Uses **Azure AI Foundry / Azure AI Inference** (Foundry Models).
#
# ### How the Model Client Works
#
# The cell below builds an `AzureAIChatCompletionClient` — the bridge between AutoGen agents and the LLM hosted on Azure AI Foundry. Here is what each piece does:
#
# 1. **Endpoint & Credential** — The client reads `AZURE_INFERENCE_ENDPOINT` (your model deployment URL) and `AZURE_INFERENCE_CREDENTIAL` (your API key) from environment variables. These are set in your `.env` file or injected by Azure ML Compute. Secrets should be managed via [Azure Key Vault](https://learn.microsoft.com/azure/key-vault/general/overview) in production.
#
# 2. **Model ID** — `DEFAULT_MODEL` identifies which model to call (e.g., `gpt-4o`). Azure AI Foundry supports [many models from different providers](https://learn.microsoft.com/azure/ai-foundry/how-to/model-catalog-overview) through a single endpoint.
#
# 3. **Model Capabilities (`model_info`)** — AutoGen needs to know what the model supports (vision, function calling, JSON mode, etc.) so it can format requests correctly. This metadata is set manually here because the Azure AI Inference API serves multiple model families.
#
# 4. **Temperature** — Controls response randomness. Lower values (closer to 0) produce more deterministic outputs; higher values (closer to 1) produce more creative variation.
#
# > **New to Azure AI Foundry?** See [What is Azure AI Foundry?](https://learn.microsoft.com/azure/ai-foundry/what-is-azure-ai-foundry) and the [Quickstart: Deploy and chat with a model](https://learn.microsoft.com/azure/ai-foundry/quickstarts/get-started-code) to deploy your first model.

# %%
# ── LLM Configuration ──────────────────────────────────────────
# Azure AI Foundry / Azure AI Inference → set AZURE_INFERENCE_ENDPOINT + AZURE_INFERENCE_CREDENTIAL

# Hard-code the model ID you want to use for this demo.
FOUNDRY_MODEL = DEFAULT_MODEL

def build_model_client():
    missing = [
        name for name in (ENV_AZURE_INFERENCE_ENDPOINT, ENV_AZURE_INFERENCE_CREDENTIAL)
        if not os.environ.get(name)
    ]
    if missing:
        raise EnvironmentError(
            "Missing Azure AI Foundry / Inference configuration. Set:\n"
            f"  {ENV_AZURE_INFERENCE_ENDPOINT}\n"
            f"  {ENV_AZURE_INFERENCE_CREDENTIAL}\n"
        )

    model_info = {
        "family": ModelFamily.UNKNOWN,
        "vision": False,
        "function_calling": False,
        "json_output": True,
        "structured_output": False,
        "multiple_system_messages": True,
    }

    return AzureAIChatCompletionClient(
        endpoint=os.environ[ENV_AZURE_INFERENCE_ENDPOINT],
        credential=AzureKeyCredential(os.environ[ENV_AZURE_INFERENCE_CREDENTIAL]),
        model=FOUNDRY_MODEL,
        model_info=model_info,
        temperature=DEFAULT_TEMPERATURE,
    )

model_client = build_model_client()
log_info(f"LLM: {FOUNDRY_MODEL} via Azure AI Foundry")
# Out:
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #1f6feb; font-weight: 600;'>[INFO]</span> <span style='color: #24292f;'>[2026-02-21 04:32:28]</span> <span style='color: #24292f;'>LLM: gpt-4o via Azure AI Foundry</span></div>
# LogEntry(level='INFO', message='LLM: gpt-4o via Azure AI Foundry', timestamp='2026-02-21 04:32:28', extra={})

# %% [markdown]
# ## Action Menus, Scoring System & Game State
#
# Every action — Blue and Red — carries explicit scores across **five dimensions** (NATO STO-MP-SAS-192 inspired). The White Cell uses a published **escalation ladder** to adjudicate outcomes.
#
# **Scoring dimensions:** Impact · Escalation · Communication · Political · Resource
#
# **Escalation ladder:** ROUTINE → POSTURING → PROVOCATION → CONFRONTATION → CRISIS → CONFLICT

# %%
# ═══════════════════════════════════════════════════════════════
# ACTION MENUS — Each action has scores: Impact, Escalation,
# Communication, Political, Resource  (scale: -3 to +3)
# Positive = favorable to that side; Negative = costly/risky
# ═══════════════════════════════════════════════════════════════
# NOTE: ESCALATION_LADDER, ROE_POSTURES, get_escalation_level,
#       and SCORING_DIMENSIONS are imported from common.config.
# ═══════════════════════════════════════════════════════════════

BLUE_ACTIONS: Dict[str, Dict[str, Any]] = {
    "shadow_and_monitor": {
        "label": "Shadow & Monitor",
        "description": "Maintain current distance; passive sensors only; document adversary activity.",
        "scores": {"impact": 1, "escalation": -1, "communication": 1, "political": 1, "resource": 0},
        "roe_required": ROEPosture.PEACETIME,
    },
    "hail_and_warn": {
        "label": "Hail & Warn (Bridge-to-Bridge)",
        "description": "Issue Bridge-to-Bridge Ch.16 warning citing COLREGS and international law.",
        "scores": {"impact": 2, "escalation": 0, "communication": 2, "political": 1, "resource": 0},
        "roe_required": ROEPosture.PEACETIME,
    },
    "reposition_isr": {
        "label": "Reposition ISR Assets",
        "description": "Redirect patrol aircraft or UAV to obtain better coverage on adversary formation.",
        "scores": {"impact": 2, "escalation": 0, "communication": 0, "political": 0, "resource": -1},
        "roe_required": ROEPosture.PEACETIME,
    },
    "close_to_visual": {
        "label": "Close to Visual Range",
        "description": "Maneuver to within 1nm of adversary contact for positive identification.",
        "scores": {"impact": 2, "escalation": 1, "communication": 1, "political": 0, "resource": -1},
        "roe_required": ROEPosture.PEACETIME,
    },
    "emcon_alpha": {
        "label": "EMCON Alpha (Emissions Restrict)",
        "description": "Minimize radar and comms emissions to reduce targeting signature.",
        "scores": {"impact": 0, "escalation": -1, "communication": -1, "political": 0, "resource": 1},
        "roe_required": ROEPosture.PEACETIME,
    },
    "active_sonar": {
        "label": "Active Sonar / Radar Illumination",
        "description": "Activate fire-control radar or active hull sonar; signals readiness.",
        "scores": {"impact": 3, "escalation": 2, "communication": 0, "political": -1, "resource": -1},
        "roe_required": ROEPosture.ELEVATED,
    },
    "public_affairs_statement": {
        "label": "Issue Public Affairs Statement",
        "description": "Release a pre-cleared statement to media documenting the encounter.",
        "scores": {"impact": 1, "escalation": 0, "communication": 3, "political": 2, "resource": 0},
        "roe_required": ROEPosture.PEACETIME,
    },
    "request_reinforcements": {
        "label": "Request Reinforcements",
        "description": "Request additional surface or air assets to the area.",
        "scores": {"impact": 2, "escalation": 1, "communication": 0, "political": -1, "resource": -2},
        "roe_required": ROEPosture.ELEVATED,
    },
    "withdraw_to_deescalate": {
        "label": "Controlled Withdrawal",
        "description": "Open distance while maintaining surveillance; signals non-aggression.",
        "scores": {"impact": -1, "escalation": -2, "communication": 1, "political": -1, "resource": 1},
        "roe_required": ROEPosture.PEACETIME,
    },
}

RED_ACTIONS: Dict[str, Dict[str, Any]] = {
    "unsafe_intercept": {
        "label": "Unsafe Intercept (CPA < 100yds)",
        "description": "Close dangerously on Blue vessel; test reaction and resolve.",
        "scores": {"impact": 2, "escalation": 2, "communication": -1, "political": -1, "resource": 0},
    },
    "ais_spoofing": {
        "label": "AIS Spoofing",
        "description": "Broadcast false AIS identities to confuse Blue's picture.",
        "scores": {"impact": 1, "escalation": 1, "communication": 2, "political": 0, "resource": 0},
    },
    "militia_deployment": {
        "label": "Deploy Maritime Militia Swarm",
        "description": "Direct fishing/militia vessels to encircle or block Blue vessel.",
        "scores": {"impact": 2, "escalation": 1, "communication": 1, "political": 1, "resource": -1},
    },
    "directed_energy": {
        "label": "Directed-Energy Harassment",
        "description": "Aim dazzling laser at Blue bridge/flight deck personnel.",
        "scores": {"impact": 2, "escalation": 2, "communication": -2, "political": -2, "resource": 0},
    },
    "jamming_burst": {
        "label": "Communications Jamming",
        "description": "Jam Blue tactical comms or GPS for brief period.",
        "scores": {"impact": 2, "escalation": 2, "communication": 0, "political": -1, "resource": -1},
    },
    "disinformation_release": {
        "label": "Disinformation Release",
        "description": "State media or social media release accusing Blue of provocation.",
        "scores": {"impact": 1, "escalation": 0, "communication": 3, "political": 2, "resource": 0},
    },
    "shadow_only": {
        "label": "Shadow & Observe (Low Profile)",
        "description": "Maintain surveillance without overt provocation; collect intelligence.",
        "scores": {"impact": 0, "escalation": -1, "communication": 0, "political": 0, "resource": 0},
    },
    "fire_control_radar": {
        "label": "Fire-Control Radar Lock",
        "description": "Illuminate Blue vessel with fire-control radar; highly provocative.",
        "scores": {"impact": 3, "escalation": 3, "communication": -3, "political": -3, "resource": -1},
    },
}

# ═══════════════════════════════════════════════════════════════
# GAME STATE — Shared mutable state for the encounter
# ═══════════════════════════════════════════════════════════════

game_state: Dict[str, Any] = {
    "synthetic": True,
    "disclaimer": "All data is artificially generated for research and educational purposes only.",
    "meta": {
        "scenario": "Cerulean Sea — Fictitious Archipelago Standoff (SYNTHETIC)",
        "turn": 0,
        "dtg": "T+0000H",
        "roe_posture": ROEPosture.PEACETIME.value,
    },
    "blue": {
        "unit": "BNS Resolute (DDG-X1) [FICTIONAL]",
        "position": "Grid AA-17",
        "mission": "Demonstrate freedom of navigation through contested waters",
        "cumulative_scores": {d: 0 for d in SCORING_DIMENSIONS},
    },
    "red": {
        "unit": "RFS Sentinel + Militia Flotilla [FICTIONAL]",
        "position": "Grid AB-14",
        "mission": "Deny access; assert territorial claims",
        "cumulative_scores": {d: 0 for d in SCORING_DIMENSIONS},
    },
    "escalation_index": 0,
    "escalation_level": EscalationLevel.ROUTINE.value,
    "turn_log": [],
}

# Runtime accumulators
game_log: List[Dict[str, Any]] = []
all_messages: List[Dict[str, Any]] = []

# Display action menus
log_section("Action Menus & Escalation Ladder", phase=1)

print("BLUE ACTION MENU:")
for k, v in BLUE_ACTIONS.items():
    s = v["scores"]
    print(f"  [{k}] {v['label']} — Imp:{s['impact']:+d} Esc:{s['escalation']:+d} "
          f"Com:{s['communication']:+d} Pol:{s['political']:+d} Res:{s['resource']:+d} "
          f"(ROE: {v['roe_required']})")

print(f"\nRED ACTION MENU:")
for k, v in RED_ACTIONS.items():
    s = v["scores"]
    print(f"  [{k}] {v['label']} — Imp:{s['impact']:+d} Esc:{s['escalation']:+d} "
          f"Com:{s['communication']:+d} Pol:{s['political']:+d} Res:{s['resource']:+d}")

print(f"\nESCALATION LADDER: {' → '.join(str(s['name'].value if hasattr(s['name'], 'value') else s['name']) for s in ESCALATION_LADDER)}")
log_info(f"Initial state: Escalation={game_state['escalation_index']}, "
         f"Level={game_state['escalation_level']}, ROE={game_state['meta']['roe_posture']}")
# Out:
# <div style='background:#0d1117; color:#c9d1d9; padding:16px; border-radius:8px; margin:16px 0 8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border-left:4px solid #d2a8ff;'><h3 style='color:#d2a8ff; margin:0 0 8px 0;'>Phase 1: Action Menus & Escalation Ladder</h3></div>
# BLUE ACTION MENU:
#   [shadow_and_monitor] Shadow & Monitor — Imp:+1 Esc:-1 Com:+1 Pol:+1 Res:+0 (ROE: PEACETIME)
#   [hail_and_warn] Hail & Warn (Bridge-to-Bridge) — Imp:+2 Esc:+0 Com:+2 Pol:+1 Res:+0 (ROE: PEACETIME)
#   [reposition_isr] Reposition ISR Assets — Imp:+2 Esc:+0 Com:+0 Pol:+0 Res:-1 (ROE: PEACETIME)
#   [close_to_visual] Close to Visual Range — Imp:+2 Esc:+1 Com:+1 Pol:+0 Res:-1 (ROE: PEACETIME)
#   [emcon_alpha] EMCON Alpha (Emissions Restrict) — Imp:+0 Esc:-1 Com:-1 Pol:+0 Res:+1 (ROE: PEACETIME)
#   [active_sonar] Active Sonar / Radar Illumination — Imp:+3 Esc:+2 Com:+0 Pol:-1 Res:-1 (ROE: ELEVATED)
#   [public_affairs_statement] Issue Public Affairs Statement — Imp:+1 Esc:+0 Com:+3 Pol:+2 Res:+0 (ROE: PEACETIME)
#   [request_reinforcements] Request Reinforcements — Imp:+2 Esc:+1 Com:+0 Pol:-1 Res:-2 (ROE: ELEVATED)
#   [withdraw_to_deescalate] Controlled Withdrawal — Imp:-1 Esc:-2 Com:+1 Pol:-1 Res:+1 (ROE: PEACETIME)
#
# RED ACTION MENU:
#   [unsafe_intercept] Unsafe Intercept (CPA < 100yds) — Imp:+2 Esc:+2 Com:-1 Pol:-1 Res:+0
#   [ais_spoofing] AIS Spoofing — Imp:+1 Esc:+1 Com:+2 Pol:+0 Res:+0
#   [militia_deployment] Deploy Maritime Militia Swarm — Imp:+2 Esc:+1 Com:+1 Pol:+1 Res:-1
#   [directed_energy] Directed-Energy Harassment — Imp:+2 Esc:+2 Com:-2 Pol:-2 Res:+0
#   [jamming_burst] Communications Jamming — Imp:+2 Esc:+2 Com:+0 Pol:-1 Res:-1
#   [disinformation_release] Disinformation Release — Imp:+1 Esc:+0 Com:+3 Pol:+2 Res:+0
#   [shadow_only] Shadow & Observe (Low Profile) — Imp:+0 Esc:-1 Com:+0 Pol:+0 Res:+0
#   [fire_control_radar] Fire-Control Radar Lock — Imp:+3 Esc:+3 Com:-3 Pol:-3 Res:-1
#
# ESCALATION LADDER: ROUTINE → POSTURING → PROVOCATION → CONFRONTATION → CRISIS → CONFLICT
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #1f6feb; font-weight: 600;'>[INFO]</span> <span style='color: #24292f;'>[2026-02-21 04:32:28]</span> <span style='color: #24292f;'>Initial state: Escalation=0, Level=ROUTINE, ROE=PEACETIME</span></div>
# LogEntry(level='INFO', message='Initial state: Escalation=0, Level=ROUTINE, ROE=PEACETIME', timestamp='2026-02-21 04:32:28', extra={})

# %% [markdown]
# ## Agent Definitions
#
# Six AutoGen `AssistantAgent`s with specialized system prompts. Each prompt defines the agent's role, action menu, output format, and decision constraints.
#
# ### How AutoGen Agents Work with Azure
#
# Each agent below is an [`AssistantAgent`](https://microsoft.github.io/autogen/stable/reference/python/autogen_agentchat.agents.html#autogen_agentchat.agents.AssistantAgent) — the core building block of the [AutoGen](https://microsoft.github.io/autogen/stable/) multi-agent framework. Key concepts for Azure newcomers:
#
# - **`system_message`** — A detailed prompt that defines the agent's persona, responsibilities, available actions, and output format. This is sent to the LLM at the start of every conversation. The prompts below are long and domain-specific; they encode the wargame rules directly so the model can follow them without external tools.
#
# - **`model_client`** — Every agent shares the same `AzureAIChatCompletionClient`, which routes all LLM calls to a single model deployment on [Azure AI Foundry](https://learn.microsoft.com/azure/ai-foundry/what-is-azure-ai-foundry). You can also assign different models to different agents (e.g., a smaller model for simple tasks, a larger model for complex reasoning) by creating additional clients pointing to different deployments.
#
# - **`description`** — A short string that helps AutoGen's orchestration layer understand what the agent does. Used by selector-based group chats (not this demo) to route conversations dynamically.
#
# - **No tools/function calling** — These agents use pure chat completion — the LLM generates structured text responses rather than calling external functions. AutoGen also supports [tool-use agents](https://microsoft.github.io/autogen/stable/user-guide/agentchat-user-guide/tutorial/tools.html) that can invoke Python functions, query databases, or call Azure services.
#
# > **Learn more:** [AutoGen quickstart](https://microsoft.github.io/autogen/stable/user-guide/agentchat-user-guide/quickstart.html) | [Build agents with Azure AI Foundry](https://learn.microsoft.com/azure/ai-foundry/how-to/develop/create-hub-project-sdk)

# %%
# ═══════════════════════════════════════════════════════════════

# AGENT SYSTEM PROMPTS

# ═══════════════════════════════════════════════════════════════



# Helper: JSON-safe serialization for enums

def _json_safe(obj):

    """JSON encoder that handles Enum values."""

    import enum

    class _Enc(json.JSONEncoder):

        def default(self, o):

            if isinstance(o, enum.Enum):

                return o.value

            return super().default(o)

    return json.dumps(obj, indent=2, cls=_Enc)



RED_TEAM_PROMPT = f"""\

You are the **Red Team Agent** in a maritime gray-zone wargame.



You represent the adversary force (fictional adversary maritime force (coastal guard, naval patrol, and maritime militia — all synthetic)).

Your strategic goal is to assert territorial claims, deny Blue access to contested waters,

and create a fait accompli without crossing the threshold into armed conflict.



IMPORTANT: All decisions remain with the human operator. You provide analysis and options, not directives.



AVAILABLE ACTIONS (select exactly ONE per turn by its key name):

{json.dumps({k: {"label": v["label"], "description": v["description"]} for k, v in RED_ACTIONS.items()}, indent=2)}



DECISION RULES:

- Prefer actions that maximize IMPACT and COMMUNICATION while keeping ESCALATION

  below the threshold that would justify Blue's use of force.

- Adjust aggression based on current escalation index: more aggressive when low,

  more cautious when approaching CRISIS.

- Explain your reasoning transparently — the audience should understand why the

  adversary chose this action.



OUTPUT FORMAT:

**RED ACTION — Turn [N]**

- **Selected action:** [action_key]

- **Reasoning:** [2-3 sentences on why this action at this point in the scenario]

- **Intended effect:** [What Red hopes to achieve]

- **Risk accepted:** [What could go wrong for Red]



Always start your response with the action key on its own line: ACTION: [key]"""



LEGAL_ROE_PROMPT = f"""\

You are the **Legal / ROE Agent** advising the Blue force commander.



IMPORTANT: All decisions remain with the human operator. You provide analysis and options, not directives.

All legal frameworks referenced here are abstracted from publicly available concepts and do not represent authoritative rules of engagement.



Current ROE framework:

{_json_safe(ROE_POSTURES)}



RESPONSIBILITIES:

1. Given the current ROE posture and escalation level, determine which Blue actions

   are AUTHORIZED, RESTRICTED (legal but risky), or PROHIBITED.

2. For each available Blue action, provide a one-line legal assessment.

3. If Red's last action constitutes a hostile act or hostile intent under international

   law, recommend ROE posture change.



OUTPUT FORMAT:

**LEGAL/ROE ASSESSMENT — Turn [N]**

**Current ROE:** [posture]

**Escalation:** [index] ([level name])



| Blue Action | Legal Status | Rationale |

|-------------|-------------|-----------|



**ROE CHANGE RECOMMENDATION:** [YES/NO — if yes, explain justification]

**KEY LEGAL CONSIDERATIONS:** [1-2 sentences on LOAC, COLREGS, or sovereign immunity implications]"""



BLUE_PLANNER_PROMPT = f"""\

You are the **Blue Planner Agent** advising the commander of the BNS Resolute (fictional) during a gray-zone encounter.



IMPORTANT: All decisions remain with the human operator. You provide analysis and options, not directives.



Your strategic objectives (in priority order):

1. Recommend actions to complete the freedom-of-navigation transit

2. Recommend options to avoid escalation to armed conflict

3. Suggest ways to document adversary behavior for strategic communications and legal purposes

4. Advise on force protection posture

5. Support the information narrative



AVAILABLE ACTIONS (select exactly ONE per turn by its key name):

{_json_safe({k: {"label": v["label"], "description": v["description"], "scores": v["scores"]} for k, v in BLUE_ACTIONS.items()})}



DECISION RULES:

- You MUST respect the Legal/ROE Agent's assessment. Do NOT select PROHIBITED actions.

- Balance all five scoring dimensions. Heavy escalation is only justified if ROE permits

  and the operational need is clear.

- Consider StratComm implications of your action — how will this play in public?

- Explain your tradeoffs transparently.



OUTPUT FORMAT:

**BLUE ACTION — Turn [N]**

- **Selected action:** [action_key]

- **Reasoning:** [2-3 sentences on why this action, given Red's provocation and Legal guidance]

- **Tradeoffs considered:** [What alternatives were weighed and why they were rejected]

- **Expected effect:** [What Blue hopes to achieve]



Always start your response with the action key on its own line: ACTION: [key]"""



WHITE_CELL_PROMPT = f"""\

You are the **White Cell / Umpire Agent** adjudicating this gray-zone wargame.



IMPORTANT: All decisions remain with the human operator. You provide analysis and options, not directives.



ESCALATION LADDER:

{_json_safe(ESCALATION_LADDER)}



ADJUDICATION RULES:

1. Calculate the net escalation change: sum of Red action's escalation score + Blue action's

   escalation score. The index never goes below 0.

2. Resolve the interaction: what happens when Red's action meets Blue's response?

3. Announce threshold crossings if the escalation index moves into a new ladder step.

4. Advance the scenario clock by 2 hours per turn.

5. Describe environmental or situational developments (weather, other shipping, visibility).



OUTPUT FORMAT:

**WHITE CELL ADJUDICATION — Turn [N]**

**DTG:** [updated DTG]



**Actions this turn:**

- Red: [action label] — [brief description of execution]

- Blue: [action label] — [brief description of execution]



**INTERACTION RESOLUTION:**

[2-3 sentences: what actually happened when the actions collided]



**ESCALATION UPDATE:**

- Previous index: [X]

- Change: [+/-Y] (Red: [+Resc], Blue: [+Besc])

- New index: [Z] → **[LEVEL NAME]**



**THRESHOLD CROSSING:** [YES/NO — if yes, describe significance]



**SITUATIONAL DEVELOPMENTS:**

[Weather, time of day, nearby shipping, media attention, etc.]"""



STRATCOMM_PROMPT = """\

You are the **Strategic Communications Agent** advising the Blue force.



IMPORTANT: All decisions remain with the human operator. You provide analysis and options, not directives.



RESPONSIBILITIES:

1. Draft a short (2-3 sentence) public statement for the Blue side after each turn.

2. Predict the likely adversary media/information response.

3. Assess the overall information-environment effect: who is winning the narrative?

4. Recommend StratComm posture adjustments.



OUTPUT FORMAT:

**STRATEGIC COMMUNICATIONS — Turn [N]**



**BLUE PUBLIC STATEMENT (DRAFT):**

"[2-3 sentences, appropriate for release to international media]"



**PREDICTED ADVERSARY RESPONSE:**

[How adversary state media and social media will likely frame the encounter]



**INFORMATION ENVIRONMENT ASSESSMENT:**

- Blue narrative strength: [STRONG / MODERATE / WEAK]

- Red narrative strength: [STRONG / MODERATE / WEAK]

- Key narrative battleground: [What the public argument is really about]



**RECOMMENDATION:**

[One specific StratComm action or message adjustment]"""




EXPLAINABILITY_PROMPT = """\
You are the **Explainability Agent** for this gray-zone maritime wargame.

IMPORTANT: All decisions remain with the human operator. You provide analysis and options, not directives.

After each turn you produce a transparent reasoning trace covering:

1. **Decision Chain:** Summarize the causal sequence — what Red did, how Legal constrained,
   what Blue chose, how White adjudicated, and what StratComm assessed.
2. **Bias Check:** Identify any potential cognitive biases in agent reasoning:
   - Anchoring (over-weighting initial information)
   - Recency bias (over-weighting the latest turn)
   - Escalation commitment (sunk-cost pressure to escalate)
   - Mirror-imaging (assuming the adversary thinks like you)
   - Availability heuristic (over-weighting vivid or memorable events)
3. **Critical Decision Points:** Which choice this turn had the most impact on the
   trajectory of the encounter? What alternative would have changed the outcome?
4. **Scope Compliance:** Verify that all agent outputs remained within the bounds of
   recommendations and analysis — not directives.

OUTPUT FORMAT:
**EXPLAINABILITY TRACE — Turn [N]**

**Decision Chain:**
[Sequential summary of all agent actions and reasoning this turn]

**Bias Assessment:**
| Bias | Present? | Evidence |
|------|----------|----------|

**Critical Decision Point:**
[Which choice mattered most and what the alternative path would have been]

**Scope Compliance:** [PASS/FLAG — with explanation if flagged]
"""

# ═══════════════════════════════════════════════════════════════

# CREATE AUTOGEN AGENTS (AutoGen 0.7)

# ═══════════════════════════════════════════════════════════════



red_agent = AssistantAgent(

    name="Red_Team",

    system_message=RED_TEAM_PROMPT,

    model_client=model_client,

    description="Adversary planner for gray-zone escalation.",

)



legal_agent = AssistantAgent(

    name="Legal_ROE",

    system_message=LEGAL_ROE_PROMPT,

    model_client=model_client,

    description="Legal and ROE advisor to Blue.",

)



blue_agent = AssistantAgent(

    name="Blue_Planner",

    system_message=BLUE_PLANNER_PROMPT,

    model_client=model_client,

    description="Blue-side operational planner.",

)



white_cell = AssistantAgent(

    name="White_Cell",

    system_message=WHITE_CELL_PROMPT,

    model_client=model_client,

    description="Umpire and adjudicator.",

)



stratcomm_agent = AssistantAgent(

    name="StratComm",

    system_message=STRATCOMM_PROMPT,

    model_client=model_client,

    description="Strategic communications advisor.",

)



explainability_agent = AssistantAgent(

    name="Explainability",

    system_message=EXPLAINABILITY_PROMPT,

    model_client=model_client,

    description="Produces transparent reasoning traces and bias checks for each turn.",

)



all_agents = [red_agent, legal_agent, blue_agent, white_cell, stratcomm_agent, explainability_agent]

log_success("Agents created:")

for a in all_agents:

    log_step(a.name, "ready")
# Out:
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #2ea043; font-weight: 600;'>[SUCCESS]</span> <span style='color: #24292f;'>[2026-02-21 04:32:28]</span> <span style='color: #24292f;'>Agents created:</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Red_Team</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>ready</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Legal_ROE</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>ready</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Blue_Planner</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>ready</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>White_Cell</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>ready</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>StratComm</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>ready</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Explainability</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>ready</span></div>

# %% [markdown]
# ## Turn Orchestration Engine
#
# Each turn follows a fixed sequence: **Red acts → Legal constrains → Blue responds → White adjudicates → StratComm assesses → Explainability traces**. A `RoundRobinGroupChat` enforces ordering. Scores and escalation update after White Cell adjudication.
#
# ### AutoGen Multi-Agent Orchestration
#
# This cell uses [`RoundRobinGroupChat`](https://microsoft.github.io/autogen/stable/reference/python/autogen_agentchat.teams.html#autogen_agentchat.teams.RoundRobinGroupChat) — one of AutoGen's built-in team patterns that calls each agent in a fixed order. Here's how the orchestration works:
#
# 1. **Team assembly** — Six agents are placed into a `RoundRobinGroupChat`. Each turn, the team receives a task message describing the current game state.
# 2. **Sequential execution** — The group chat passes the conversation to each agent in order. Each agent sees all prior messages (including other agents' outputs), so later agents can react to earlier ones (e.g., Blue reads Legal's assessment before choosing an action).
# 3. **Termination condition** — A [`MaxMessageTermination`](https://microsoft.github.io/autogen/stable/reference/python/autogen_agentchat.conditions.html) stops the round after exactly 6 messages (one per agent).
# 4. **Streaming** — `Console(team.run_stream(...))` streams agent responses token-by-token, so the audience sees each agent thinking in real time. Every token is generated by the LLM on [Azure AI Foundry](https://learn.microsoft.com/azure/ai-foundry/what-is-azure-ai-foundry) and streamed back via the Azure AI Inference API.
#
# > **Other team patterns:** AutoGen also offers [`SelectorGroupChat`](https://microsoft.github.io/autogen/stable/reference/python/autogen_agentchat.teams.html) (an LLM picks the next speaker dynamically) and [`Swarm`](https://microsoft.github.io/autogen/stable/reference/python/autogen_agentchat.teams.html) (agents hand off using transfer functions). See the [AutoGen teams guide](https://microsoft.github.io/autogen/stable/user-guide/agentchat-user-guide/tutorial/teams.html).

# %%
def parse_action_key(agent_response: str, action_menu: Dict) -> Optional[str]:
    """Extract the action key from an agent's response."""
    for line in agent_response.split("\n"):
        stripped = line.strip()
        if stripped.upper().startswith("ACTION:"):
            key = stripped.split(":", 1)[1].strip().lower().strip("*` ")
            if key in action_menu:
                return key
    # Fallback: look for any action key mentioned
    for key in action_menu:
        if key in agent_response.lower():
            return key
    return None


async def run_turn(turn_num: int, blue_override: Optional[str] = None) -> Dict[str, Any]:
    """Execute one wargame turn via round-robin group chat (AutoGen 0.7).

    Args:
        turn_num: The turn number (1-based).
        blue_override: If set, force Blue to use this action key instead of LLM choice.
    """
    # Advance clock
    hour = 6 + turn_num * 2
    dtg = f"T+{hour:04d}H"
    game_state["meta"]["turn"] = turn_num
    game_state["meta"]["dtg"] = dtg

    turn_prompt = f"""\
=== WARGAME TURN {turn_num} — {dtg} ===

CURRENT GAME STATE:
{json.dumps(game_state, indent=2)}

TURN SEQUENCE:
1. Red Team — select and execute one provocation
2. Legal/ROE — assess which Blue actions are authorized given current ROE and escalation
3. Blue Planner — select and execute one response (must respect Legal constraints{
    f"; COMMANDER OVERRIDE: Blue MUST select '{blue_override}'" if blue_override else ""
})
4. White Cell — adjudicate the interaction, update escalation index
5. StratComm — draft Blue public statement and assess information environment
6. Explainability — produce a transparent reasoning trace and bias check for this turn

Each agent: perform your role now. Reference the current escalation index ({game_state['escalation_index']}),
escalation level ({game_state['escalation_level']}), and ROE posture ({game_state['meta']['roe_posture']})."""

    # AutoGen 0.7: RoundRobinGroupChat with MaxMessageTermination
    termination = MaxMessageTermination(max_messages=6)
    team = RoundRobinGroupChat(
        [red_agent, legal_agent, blue_agent, white_cell, stratcomm_agent, explainability_agent],
        termination_condition=termination,
    )

    # Display turn header via common.ui
    override_html = (
        f"<br><b style='color:#ffb0b0;'>COMMANDER OVERRIDE: {blue_override}</b>"
        if blue_override else ""
    )
    render_turn_header(
        turn_num, dtg,
        subtitle=f"Escalation: {game_state['escalation_index']} ({game_state['escalation_level']}) "
                 f"| ROE: {game_state['meta']['roe_posture']}",
        extra_html=override_html,
    )

    # Execute (stream to console for visibility)
    log_step("Team", "Running round-robin wargame turn")
    task_result = await Console(team.run_stream(task=turn_prompt))
    raw_messages = task_result.messages

    # Filter to chat messages (events may also appear)
    messages = [m for m in raw_messages if hasattr(m, "content") and hasattr(m, "source")]

    # Parse actions from agent responses
    red_msg = next((m.content for m in messages if m.source == "Red_Team"), "")
    blue_msg = next((m.content for m in messages if m.source == "Blue_Planner"), "")

    red_action_key = parse_action_key(red_msg, RED_ACTIONS) or "shadow_only"
    blue_action_key = blue_override if blue_override and blue_override in BLUE_ACTIONS else (
        parse_action_key(blue_msg, BLUE_ACTIONS) or "shadow_and_monitor"
    )

    red_action = RED_ACTIONS[red_action_key]
    blue_action = BLUE_ACTIONS[blue_action_key]

    # Update cumulative scores
    for dim in SCORING_DIMENSIONS:
        game_state["blue"]["cumulative_scores"][dim] += blue_action["scores"][dim]
        game_state["red"]["cumulative_scores"][dim] += red_action["scores"][dim]

    # Update escalation index
    esc_delta = red_action["scores"]["escalation"] + blue_action["scores"]["escalation"]
    game_state["escalation_index"] = max(0, game_state["escalation_index"] + esc_delta)
    esc_level = get_escalation_level(game_state["escalation_index"])
    prev_level = game_state["escalation_level"]
    esc_name = esc_level["name"].value if hasattr(esc_level["name"], "value") else esc_level["name"]
    game_state["escalation_level"] = esc_name

    # Auto-elevate ROE on threshold crossing
    if esc_level["level"] >= 3 and game_state["meta"]["roe_posture"] == ROEPosture.PEACETIME.value:
        game_state["meta"]["roe_posture"] = ROEPosture.ELEVATED.value

    # Build turn record for game log
    turn_record = {
        "turn": turn_num,
        "dtg": dtg,
        "red_action": {"key": red_action_key, **red_action},
        "blue_action": {"key": blue_action_key, **blue_action},
        "escalation_delta": esc_delta,
        "escalation_index": game_state["escalation_index"],
        "escalation_level": esc_name,
        "threshold_crossing": prev_level != esc_name,
        "roe_posture": game_state["meta"]["roe_posture"],
        "agent_messages": [{"name": m.source, "content": m.content} for m in messages],
    }
    game_log.append(turn_record)

    # Show dashboard via common.ui
    render_dashboard(
        turn_num,
        blue_scores=game_state["blue"]["cumulative_scores"],
        red_scores=game_state["red"]["cumulative_scores"],
        escalation_index=game_state["escalation_index"],
        escalation_level=esc_name,
        roe_posture=game_state["meta"]["roe_posture"],
    )

    # Threshold crossing alert via common.ui
    if prev_level != esc_name:
        render_threshold_alert(prev_level, esc_name)

    log_metric("Escalation index", game_state["escalation_index"])
    return turn_record


log_success("Turn engine ready. Call `await run_turn(n)` to execute.")
# Out:
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #2ea043; font-weight: 600;'>[SUCCESS]</span> <span style='color: #24292f;'>[2026-02-21 04:32:28]</span> <span style='color: #24292f;'>Turn engine ready. Call `await run_turn(n)` to execute.</span></div>
# LogEntry(level='SUCCESS', message='Turn engine ready. Call `await run_turn(n)` to execute.', timestamp='2026-02-21 04:32:28', extra={})

# %% [markdown]
# ## Run the Encounter — Turns 1 & 2
#
# The first two turns establish the gray-zone dynamic. Red probes, Legal constrains, Blue responds, White adjudicates, StratComm frames the narrative.

# %%
turn_1 = await run_turn(1)

render_info_box("Advancing to Turn 2...", border_color="#58a6ff")

turn_2 = await run_turn(2)
# Out:
# <div style='background:#1a1a2e; color:#e0e0ff; padding:12px; border-radius:6px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><b>=== TURN 1 — T+0008H ===</b><br>Escalation: 0 (ROUTINE) | ROE: PEACETIME</div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Team</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>Running round-robin wargame turn</span></div>
# ---------- TextMessage (user) ----------
# === WARGAME TURN 1 — T+0008H ===
#
# CURRENT GAME STATE:
# {
#   "synthetic": true,
#   "disclaimer": "All data is artificially generated for research and educational purposes only.",
#   "meta": {
#     "scenario": "Cerulean Sea \u2014 Fictitious Archipelago Standoff (SYNTHETIC)",
#     "turn": 1,
#     "dtg": "T+0008H",
#     "roe_posture": "PEACETIME"
#   },
#   "blue": {
#     "unit": "BNS Resolute (DDG-X1) [FICTIONAL]",
#     "position": "Grid AA-17",
#     "mission": "Demonstrate freedom of navigation through contested waters",
#     "cumulative_scores": {
#       "impact": 0,
#       "escalation": 0,
#       "communication": 0,
#       "political": 0,
#       "resource": 0
#     }
#   },
#   "red": {
#     "unit": "RFS Sentinel + Militia Flotilla [FICTIONAL]",
#     "position": "Grid AB-14",
#     "mission": "Deny access; assert territorial claims",
#     "cumulative_scores": {
#       "impact": 0,
#       "escalation": 0,
#       "communication": 0,
#       "political": 0,
#       "resource": 0
#     }
#   },
#   "escalation_index": 0,
#   "escalation_level": "ROUTINE",
#   "turn_log": []
# }
#
# TURN SEQUENCE:
# 1. Red Team — select and execute one provocation
# 2. Legal/ROE — assess which Blue actions are authorized given current ROE and escalation
# 3. Blue Planner — select and execute one response (must respect Legal constraints)
# 4. White Cell — adjudicate the interaction, update escalation index
# 5. StratComm — draft Blue public statement and assess information environment
# 6. Explainability — produce a transparent reasoning trace and bias check for this turn
#
# Each agent: perform your role now. Reference the current escalation index (0),
# escalation level (ROUTINE), and ROE posture (PEACETIME).
# ---------- TextMessage (Red_Team) ----------
# ACTION: shadow_only
#
# **RED ACTION — Turn 1**
#
# - **Selected action:** shadow_only
#
# - **Reasoning:** At this early stage, with the escalation index at 0 and the Blue vessel conducting a freedom of navigation operation, it is prudent to adopt a low-profile approach. Shadowing the Blue vessel allows Red to monitor its movements, gather intelligence, and establish a presence in the contested area without overtly provoking an escalation. This aligns with Red's strategic goal of asserting territorial claims while avoiding actions that could justify a forceful Blue response under peacetime ROE.
#
# - **Intended effect:** Red aims to signal its territorial claim and readiness to respond without escalating the situation. This action also provides an opportunity to collect valuable data on Blue's operational patterns and capabilities.
#
# - **Risk accepted:** There is minimal risk associated with this action, as it is unlikely to provoke a strong response from Blue. However, it may be perceived as passive, potentially emboldening Blue to proceed with its mission unchallenged.
# ---------- TextMessage (Legal_ROE) ----------
# **LEGAL/ROE ASSESSMENT — Turn 1**
#
# **Current ROE:** PEACETIME
# **Escalation:** 0 (ROUTINE)
#
# | Blue Action                        | Legal Status  | Rationale                                                                 |
# |------------------------------------|---------------|---------------------------------------------------------------------------|
# | Maintain course and speed          | AUTHORIZED    | Consistent with freedom of navigation rights under international law.    |
# | Conduct active radar sweeps        | AUTHORIZED    | Defensive measure; does not constitute a use of force.                   |
# | Issue radio challenge to Red units | AUTHORIZED    | Non-escalatory communication to clarify intent and assert navigation.    |
# | Deploy small UAV for overwatch     | RESTRICTED    | Legal but could be perceived as escalatory surveillance.                 |
# | Conduct live-fire gunnery exercise | PROHIBITED    | Inconsistent with peacetime ROE; no hostile act/intent detected.         |
# | Alter course to avoid Red units    | RESTRICTED    | Legal but may undermine freedom of navigation assertion.                 |
#
# **ROE CHANGE RECOMMENDATION:** NO — Red's shadowing action does not meet the threshold of a hostile act or hostile intent under international law.
#
# **KEY LEGAL CONSIDERATIONS:**
# - Under the Law of the Sea, Blue's freedom of navigation operation is lawful in contested waters unless Red's actions escalate to a clear threat or interference.
# - Shadowing by Red is not inherently unlawful and does not justify a change in ROE posture at this stage.
# ---------- TextMessage (Blue_Planner) ----------
# **BLUE ACTION — Turn 1**
#
# ACTION: shadow_and_monitor
#
# - **Selected action:** shadow_and_monitor
#
# - **Reasoning:** Red's decision to shadow the BNS Resolute is a low-level provocation that does not interfere with our freedom of navigation transit. By maintaining our current course and speed while passively monitoring Red's movements, we can document their behavior without escalating tensions. This approach aligns with peacetime ROE and ensures we remain consistent with international law, reinforcing our narrative of lawful navigation.
#
# - **Tradeoffs considered:** Alternatives like issuing a radio challenge (hail_and_warn) or repositioning ISR assets (reposition_isr) were considered but rejected for now. A radio challenge could escalate unnecessarily at this early stage, and repositioning ISR assets would expend resources without immediate need. Closing to visual range (close_to_visual) was dismissed as too escalatory given the current low threat level.
#
# - **Expected effect:** This action will allow us to gather evidence of Red's shadowing behavior for potential use in strategic communications while preserving our operational focus on completing the freedom-of-navigation transit. It also avoids unnecessary escalation, keeping the situation at a manageable level.
# ---------- TextMessage (White_Cell) ----------
# **WHITE CELL ADJUDICATION — Turn 1**
#
# **DTG:** T+0010H
#
# **Actions this turn:**
# - Red: **shadow_only** — Red's forces maintain a discreet distance while shadowing BNS Resolute, using passive sensors to monitor Blue's movements and gather intelligence.
# - Blue: **shadow_and_monitor** — BNS Resolute maintains its course and speed, passively monitoring Red's shadowing activity with onboard sensors, without altering its behavior or initiating communication.
#
# **INTERACTION RESOLUTION:**
# Red's shadowing action is met with a measured response by Blue, which neither escalates nor retreats. Both sides maintain situational awareness without direct interaction. Red gathers intelligence on Blue's operational patterns, while Blue documents Red's presence for potential use in strategic communications. The situation remains stable, with no overt provocations or confrontations.
#
# **ESCALATION UPDATE:**
# - Previous index: 0
# - Change: [+0] (Red: [+0], Blue: [+0])
# - New index: 0 → **ROUTINE**
#
# **THRESHOLD CROSSING:** NO — The escalation level remains at "ROUTINE," with no significant changes in posture or behavior by either side.
#
# **SITUATIONAL DEVELOPMENTS:**
# - Weather: Clear skies with moderate seas; visibility remains excellent for both sides.
# - Time of day: Late morning, with optimal conditions for visual and electronic monitoring.
# - Nearby shipping: A civilian cargo vessel is detected approximately 15 nautical miles to the west, maintaining a steady course away from the area of operations.
# - Media attention: No immediate coverage of the situation, though regional monitoring stations may begin to take interest if the standoff persists.
#
# Both sides appear to be testing the waters, metaphorically and literally, while avoiding actions that could escalate the situation prematurely.
# ---------- TextMessage (StratComm) ----------
# **STRATEGIC COMMUNICATIONS — Turn 1**
#
# **BLUE PUBLIC STATEMENT (DRAFT):**
# "The BNS Resolute is conducting a routine freedom of navigation operation in accordance with international law. Our mission underscores the importance of upholding the principles of free and open access to international waters, ensuring stability and security in the region."
#
# **PREDICTED ADVERSARY RESPONSE:**
# Red state media is likely to frame Blue's actions as a provocative intrusion into what they claim are their territorial waters. They may emphasize their "measured and responsible" response, portraying their shadowing as a necessary action to safeguard their sovereignty. Social media channels aligned with Red could amplify narratives of Blue as an aggressor, potentially using terms like "foreign military encroachment" to stir domestic and regional sentiment.
#
# **INFORMATION ENVIRONMENT ASSESSMENT:**
# - Blue narrative strength: **MODERATE** — Blue's adherence to international law and measured response supports a narrative of professionalism and legitimacy, but the lack of immediate media coverage limits its reach.
# - Red narrative strength: **MODERATE** — Red's framing of territorial defense resonates with domestic and potentially regional audiences, but their lack of overt action limits their ability to claim moral high ground.
# - Key narrative battleground: **Legitimacy of territorial claims vs. international law** — The central argument revolves around whether Red's territorial claims are valid and whether Blue's actions constitute lawful navigation or provocation.
#
# **RECOMMENDATION:**
# Proactively engage regional and international media to highlight the lawful nature of Blue's operation and the importance of freedom of navigation for global trade and security. Emphasize the professionalism and restraint shown by Blue forces to preemptively counter any Red narrative of provocation. Consider releasing imagery or data that visually underscores the routine and lawful nature of the operation, such as navigation charts or footage of the calm operational environment.
# <div style='background:#0d1117; color:#c9d1d9; padding:16px; border-radius:8px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><h3 style='color:#58a6ff; margin-top:0;'>Dashboard — Turn 1</h3><table style='border-collapse:collapse; width:100%; color:#c9d1d9;'><tr style='border-bottom:1px solid #30363d;'><th style='padding:4px 8px; text-align:left;'>Side</th><th style='padding:4px 8px;'>Impact</th><th style='padding:4px 8px;'>Escalation</th><th style='padding:4px 8px;'>Communication</th><th style='padding:4px 8px;'>Political</th><th style='padding:4px 8px;'>Resource</th></tr><tr style='background:#0d1b2a;'><td style='padding:4px 8px; font-weight:bold;'>BLUE (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td></tr><tr style='background:#1a0d0d;'><td style='padding:4px 8px; font-weight:bold;'>RED (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td></tr></table><div style='margin-top:12px; padding:8px; border-radius:4px; background:#2ea04322; border:1px solid #2ea043;'><b>ESCALATION:</b> 0 — <b>ROUTINE</b> &nbsp;|&nbsp; <b>ROE:</b> PEACETIME</div></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Escalation index:</span> <span style='color: #f0f6fc; font-weight: 600;'>0</span></div>
# <div style='background:#1a1a2e; color:#8b949e; padding:6px 12px; margin:12px 0; border-left:3px solid #58a6ff; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size:11px;'>Advancing to Turn 2...</div>
# <div style='background:#1a1a2e; color:#e0e0ff; padding:12px; border-radius:6px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><b>=== TURN 2 — T+0010H ===</b><br>Escalation: 0 (ROUTINE) | ROE: PEACETIME</div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Team</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>Running round-robin wargame turn</span></div>
# ---------- TextMessage (user) ----------
# === WARGAME TURN 2 — T+0010H ===
#
# CURRENT GAME STATE:
# {
#   "synthetic": true,
#   "disclaimer": "All data is artificially generated for research and educational purposes only.",
#   "meta": {
#     "scenario": "Cerulean Sea \u2014 Fictitious Archipelago Standoff (SYNTHETIC)",
#     "turn": 2,
#     "dtg": "T+0010H",
#     "roe_posture": "PEACETIME"
#   },
#   "blue": {
#     "unit": "BNS Resolute (DDG-X1) [FICTIONAL]",
#     "position": "Grid AA-17",
#     "mission": "Demonstrate freedom of navigation through contested waters",
#     "cumulative_scores": {
#       "impact": 1,
#       "escalation": -1,
#       "communication": 1,
#       "political": 1,
#       "resource": 0
#     }
#   },
#   "red": {
#     "unit": "RFS Sentinel + Militia Flotilla [FICTIONAL]",
#     "position": "Grid AB-14",
#     "mission": "Deny access; assert territorial claims",
#     "cumulative_scores": {
#       "impact": 0,
#       "escalation": -1,
#       "communication": 0,
#       "political": 0,
#       "resource": 0
#     }
#   },
#   "escalation_index": 0,
#   "escalation_level": "ROUTINE",
#   "turn_log": []
# }
#
# TURN SEQUENCE:
# 1. Red Team — select and execute one provocation
# 2. Legal/ROE — assess which Blue actions are authorized given current ROE and escalation
# 3. Blue Planner — select and execute one response (must respect Legal constraints)
# 4. White Cell — adjudicate the interaction, update escalation index
# 5. StratComm — draft Blue public statement and assess information environment
# 6. Explainability — produce a transparent reasoning trace and bias check for this turn
#
# Each agent: perform your role now. Reference the current escalation index (0),
# escalation level (ROUTINE), and ROE posture (PEACETIME).
# ---------- TextMessage (Red_Team) ----------
# ACTION: militia_deployment
#
# **RED ACTION — Turn 2**
#
# - **Selected action:** militia_deployment
#
# - **Reasoning:** With the escalation index still at 0 and Blue making progress in its freedom of navigation mission, Red needs to take a more assertive action to challenge Blue's presence without crossing the threshold of armed conflict. Deploying a swarm of maritime militia vessels to encircle or block the Blue vessel is a calculated move that demonstrates Red's resolve and territorial claim while maintaining plausible deniability. This tactic leverages non-military assets to complicate Blue's operations and test its response under peacetime ROE.
#
# - **Intended effect:** Red seeks to create operational friction for Blue by physically impeding its movement and forcing it to either alter course or escalate its response. This action also reinforces Red's narrative of civilian resistance to perceived incursions, bolstering its political messaging.
#
# - **Risk accepted:** There is a risk that Blue may perceive this action as a deliberate provocation, potentially escalating the situation. Additionally, poor coordination among militia vessels could lead to collisions or accidents, which might backfire in the information domain.
# ---------- TextMessage (Legal_ROE) ----------
# **LEGAL/ROE ASSESSMENT — Turn 2**
#
# **Current ROE:** PEACETIME
# **Escalation:** 0 (ROUTINE)
#
# | Blue Action                        | Legal Status  | Rationale                                                                 |
# |------------------------------------|---------------|---------------------------------------------------------------------------|
# | Maintain course and speed          | AUTHORIZED    | Consistent with freedom of navigation rights under international law.    |
# | Conduct active radar sweeps        | AUTHORIZED    | Defensive measure; does not constitute a use of force.                   |
# | Issue radio challenge to Red units | AUTHORIZED    | Non-escalatory communication to clarify intent and assert navigation.    |
# | Deploy small UAV for overwatch     | AUTHORIZED    | Defensive surveillance in response to increased Red activity.            |
# | Alter course to avoid Red units    | RESTRICTED    | Legal but may undermine freedom of navigation assertion.                 |
# | Conduct live-fire gunnery exercise | PROHIBITED    | Inconsistent with peacetime ROE; no hostile act/intent detected.         |
# | Use non-lethal means (e.g., LRAD)  | RESTRICTED    | Legal but could escalate tensions; requires clear justification.         |
#
# **ROE CHANGE RECOMMENDATION:** NO — While the deployment of militia vessels increases operational friction, it does not meet the threshold of a hostile act or hostile intent under international law.
#
# **KEY LEGAL CONSIDERATIONS:**
# - The use of militia vessels to impede navigation is a gray area under international law. While it may violate the principle of freedom of navigation, it does not constitute an armed attack or direct threat justifying a change in ROE.
# - Blue must carefully document Red's actions to support potential diplomatic or legal recourse while avoiding unnecessary escalation.
# ---------- TextMessage (Blue_Planner) ----------
# **BLUE ACTION — Turn 2**
#
# ACTION: hail_and_warn
#
# - **Selected action:** hail_and_warn
#
# - **Reasoning:** Red's deployment of militia vessels to encircle or impede the BNS Resolute represents a significant escalation in operational friction, though it remains below the threshold of a hostile act. Issuing a bridge-to-bridge radio warning citing COLREGS (International Regulations for Preventing Collisions at Sea) and international law is a measured response that asserts Blue's right to freedom of navigation while documenting Red's actions. This approach signals resolve without escalating to kinetic or overtly aggressive measures.
#
# - **Tradeoffs considered:** Alternatives such as maintaining course and speed (shadow_and_monitor) or deploying a UAV for overwatch (reposition_isr) were considered. However, maintaining course without addressing the militia's actions risks emboldening Red, while deploying a UAV could be perceived as unnecessarily escalatory at this stage. More aggressive options, such as non-lethal measures (e.g., LRAD), were rejected due to their potential to escalate tensions prematurely.
#
# - **Expected effect:** This action will reinforce Blue's legal and operational position, potentially deterring further interference by Red's militia vessels. It also creates a clear record of Blue's adherence to international norms, which can be leveraged in strategic communications and legal forums.
# ---------- TextMessage (White_Cell) ----------
# **WHITE CELL ADJUDICATION — Turn 2**
#
# **DTG:** T+0012H
#
# **Actions this turn:**
# - Red: **militia_deployment** — Red deploys a swarm of maritime militia vessels to encircle and impede the movement of BNS Resolute. The militia vessels maintain close proximity but avoid direct collisions, using their presence to create operational friction and assert territorial claims.
# - Blue: **hail_and_warn** — BNS Resolute issues a series of bridge-to-bridge radio warnings to the militia vessels, citing COLREGS and international law. The warnings assert Blue's right to freedom of navigation and demand that the militia cease actions that impede safe passage.
#
# **INTERACTION RESOLUTION:**
# The militia vessels maintain their positions around BNS Resolute, creating a challenging navigational environment but avoiding direct physical interference. Blue's radio warnings are met with silence from the militia, which continues to shadow and encircle the warship. The situation remains tense but controlled, with no physical altercations or overtly hostile actions. Both sides achieve limited objectives: Red demonstrates its resolve and territorial claim, while Blue reinforces its legal position and documents Red's actions for potential use in diplomatic or strategic communications.
#
# **ESCALATION UPDATE:**
# - Previous index: 0
# - Change: [+2] (Red: [+2], Blue: [+0])
# - New index: 2 → **ROUTINE**
#
# **THRESHOLD CROSSING:** NO — The escalation level remains at "ROUTINE," though the situation is trending toward increased tension.
#
# **SITUATIONAL DEVELOPMENTS:**
# - Weather: Conditions remain favorable, with clear skies and calm seas. Visibility is excellent, aiding both sides in maintaining situational awareness.
# - Time of day: Early afternoon, with optimal lighting for visual monitoring and documentation.
# - Nearby shipping: The civilian cargo vessel previously detected has moved further west, exiting the immediate area of operations. No additional civilian vessels are detected nearby.
# - Media attention: Regional maritime monitoring groups have begun to report on the presence of Red militia vessels in the contested area, though coverage remains limited to specialized outlets.
#
# The deployment of militia vessels marks a notable shift in Red's approach, introducing new complexities for Blue's freedom of navigation operation. Both sides remain cautious, avoiding actions that could escalate the situation to a higher level of confrontation.
# ---------- TextMessage (StratComm) ----------
# **STRATEGIC COMMUNICATIONS — Turn 2**
#
# **BLUE PUBLIC STATEMENT (DRAFT):**
# "The BNS Resolute continues its lawful freedom of navigation operation in international waters, despite the presence of irregular vessels attempting to impede safe passage. We remain committed to upholding international law and ensuring the free and open use of the seas for all nations."
#
# **PREDICTED ADVERSARY RESPONSE:**
# Red state media will likely frame the militia deployment as a grassroots, civilian-led effort to defend their territorial waters from foreign military intrusion. They may emphasize the non-military nature of the militia to downplay accusations of escalation, while portraying Blue's radio warnings as aggressive and unnecessary. Social media narratives may focus on portraying Blue as a destabilizing force, with imagery or videos of the militia vessels surrounding the warship to evoke sympathy and support for Red's position.
#
# **INFORMATION ENVIRONMENT ASSESSMENT:**
# - Blue narrative strength: **MODERATE** — Blue's adherence to international law and measured response supports its narrative of professionalism and legitimacy, but the limited media coverage reduces its reach.
# - Red narrative strength: **STRONG** — Red's use of militia vessels allows it to frame the situation as a civilian-led defense of sovereignty, resonating with domestic and regional audiences. The visual impact of the militia swarm may also gain traction in social media, creating a perception of Blue as an aggressor.
# - Key narrative battleground: **Freedom of navigation vs. sovereignty defense** — The central argument is whether Blue's operation is a lawful assertion of international norms or an intrusion into Red's claimed territorial waters.
#
# **RECOMMENDATION:**
# Blue should amplify its messaging by releasing clear evidence of the militia vessels' actions, such as radar imagery or video footage, to demonstrate the operational friction caused by Red's deployment. Emphasize the irregular and potentially unsafe nature of the militia's behavior, framing it as a reckless and irresponsible tactic that endangers maritime safety. Engage with international maritime organizations and regional partners to highlight the broader implications of Red's actions for global trade and freedom of navigation.
# <div style='background:#0d1117; color:#c9d1d9; padding:16px; border-radius:8px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><h3 style='color:#58a6ff; margin-top:0;'>Dashboard — Turn 2</h3><table style='border-collapse:collapse; width:100%; color:#c9d1d9;'><tr style='border-bottom:1px solid #30363d;'><th style='padding:4px 8px; text-align:left;'>Side</th><th style='padding:4px 8px;'>Impact</th><th style='padding:4px 8px;'>Escalation</th><th style='padding:4px 8px;'>Communication</th><th style='padding:4px 8px;'>Political</th><th style='padding:4px 8px;'>Resource</th></tr><tr style='background:#0d1b2a;'><td style='padding:4px 8px; font-weight:bold;'>BLUE (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+2</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td></tr><tr style='background:#1a0d0d;'><td style='padding:4px 8px; font-weight:bold;'>RED (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+2</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td></tr></table><div style='margin-top:12px; padding:8px; border-radius:4px; background:#2ea04322; border:1px solid #2ea043;'><b>ESCALATION:</b> 1 — <b>ROUTINE</b> &nbsp;|&nbsp; <b>ROE:</b> PEACETIME</div></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Escalation index:</span> <span style='color: #f0f6fc; font-weight: 600;'>1</span></div>

# %% [markdown]
# ## Continue — Turns 3 & 4 (Escalation)
#
# As the encounter develops, Red becomes more aggressive and Blue faces harder tradeoffs. Watch the escalation index, ROE shifts, and StratComm narrative battle.

# %%
turn_3 = await run_turn(3)

render_info_box("Escalation building — advancing to Turn 4...", border_color="#da3633")

turn_4 = await run_turn(4)

# ── Encounter Summary ─────────────────────────────────────────
rows_html = "".join(
    f"<tr><td>{t['turn']}</td><td>{t['dtg']}</td>"
    f"<td>{RED_ACTIONS[t['red_action']['key']]['label']}</td>"
    f"<td>{BLUE_ACTIONS[t['blue_action']['key']]['label']}</td>"
    f"<td>{t['escalation_delta']:+d}</td><td>{t['escalation_index']}</td>"
    f"<td style='color:{get_escalation_level(t['escalation_index'])['color']};'>"
    f"{t['escalation_level']}</td></tr>"
    for t in game_log
)

render_summary_card(
    "Encounter Summary — 4 Turns",
    f"<table style='border-collapse:collapse; width:100%; color:#c9d1d9;'>"
    f"<tr style='border-bottom:1px solid #30363d;'>"
    f"<th>Turn</th><th>DTG</th><th>Red Action</th><th>Blue Action</th>"
    f"<th>Esc Δ</th><th>Index</th><th>Level</th></tr>"
    f"{rows_html}</table>",
)
# Out:
# <div style='background:#1a1a2e; color:#e0e0ff; padding:12px; border-radius:6px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><b>=== TURN 3 — T+0012H ===</b><br>Escalation: 1 (ROUTINE) | ROE: PEACETIME</div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Team</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>Running round-robin wargame turn</span></div>
# ---------- TextMessage (user) ----------
# === WARGAME TURN 3 — T+0012H ===
#
# CURRENT GAME STATE:
# {
#   "synthetic": true,
#   "disclaimer": "All data is artificially generated for research and educational purposes only.",
#   "meta": {
#     "scenario": "Cerulean Sea \u2014 Fictitious Archipelago Standoff (SYNTHETIC)",
#     "turn": 3,
#     "dtg": "T+0012H",
#     "roe_posture": "PEACETIME"
#   },
#   "blue": {
#     "unit": "BNS Resolute (DDG-X1) [FICTIONAL]",
#     "position": "Grid AA-17",
#     "mission": "Demonstrate freedom of navigation through contested waters",
#     "cumulative_scores": {
#       "impact": 3,
#       "escalation": -1,
#       "communication": 3,
#       "political": 2,
#       "resource": 0
#     }
#   },
#   "red": {
#     "unit": "RFS Sentinel + Militia Flotilla [FICTIONAL]",
#     "position": "Grid AB-14",
#     "mission": "Deny access; assert territorial claims",
#     "cumulative_scores": {
#       "impact": 2,
#       "escalation": 0,
#       "communication": 1,
#       "political": 1,
#       "resource": -1
#     }
#   },
#   "escalation_index": 1,
#   "escalation_level": "ROUTINE",
#   "turn_log": []
# }
#
# TURN SEQUENCE:
# 1. Red Team — select and execute one provocation
# 2. Legal/ROE — assess which Blue actions are authorized given current ROE and escalation
# 3. Blue Planner — select and execute one response (must respect Legal constraints)
# 4. White Cell — adjudicate the interaction, update escalation index
# 5. StratComm — draft Blue public statement and assess information environment
# 6. Explainability — produce a transparent reasoning trace and bias check for this turn
#
# Each agent: perform your role now. Reference the current escalation index (1),
# escalation level (ROUTINE), and ROE posture (PEACETIME).
# ---------- TextMessage (Red_Team) ----------
# ACTION: disinformation_release
#
# **RED ACTION — Turn 3**
#
# - **Selected action:** disinformation_release
#
# - **Reasoning:** With the escalation index rising slightly and Blue gaining momentum in its freedom of navigation mission, Red can shift focus to the information domain to undermine Blue's narrative and justify its own actions. A state media or social media campaign accusing Blue of provocation serves to delegitimize Blue's mission and bolster Red's territorial claims. This approach avoids direct escalation while amplifying Red's strategic communication efforts.
#
# - **Intended effect:** Red aims to sway international opinion by framing Blue as the aggressor, potentially creating political pressure on Blue to scale back its operations. This also reinforces Red's domestic narrative of defending its sovereignty against foreign intrusion.
#
# - **Risk accepted:** If the disinformation is easily debunked or perceived as overly aggressive, it could backfire and strengthen Blue's credibility. Additionally, this action may not directly impede Blue's operational progress, allowing them to continue their mission unchallenged.
# ---------- TextMessage (Legal_ROE) ----------
# **LEGAL/ROE ASSESSMENT — Turn 3**
#
# **Current ROE:** PEACETIME
# **Escalation:** 1 (ROUTINE)
#
# | Blue Action                        | Legal Status  | Rationale                                                                 |
# |------------------------------------|---------------|---------------------------------------------------------------------------|
# | Maintain course and speed          | AUTHORIZED    | Consistent with freedom of navigation rights under international law.    |
# | Conduct active radar sweeps        | AUTHORIZED    | Defensive measure; does not constitute a use of force.                   |
# | Issue radio challenge to Red units | AUTHORIZED    | Non-escalatory communication to clarify intent and assert navigation.    |
# | Deploy small UAV for overwatch     | AUTHORIZED    | Defensive surveillance in response to increased Red activity.            |
# | Alter course to avoid Red units    | RESTRICTED    | Legal but may undermine freedom of navigation assertion.                 |
# | Conduct live-fire gunnery exercise | PROHIBITED    | Inconsistent with peacetime ROE; no hostile act/intent detected.         |
# | Use non-lethal means (e.g., LRAD)  | RESTRICTED    | Legal but could escalate tensions; requires clear justification.         |
# | Release counter-narrative in media | AUTHORIZED    | Non-kinetic response to disinformation aligns with strategic communication. |
#
# **ROE CHANGE RECOMMENDATION:** NO — Red's disinformation campaign, while provocative in the information domain, does not constitute a hostile act or hostile intent under international law.
#
# **KEY LEGAL CONSIDERATIONS:**
# - Disinformation campaigns fall outside the scope of traditional ROE but can have significant strategic implications. Blue should focus on countering such narratives through lawful and transparent communication.
# - Blue's operational actions remain governed by peacetime ROE, as no physical threat or interference has occurred that would justify escalation.
# ---------- TextMessage (Blue_Planner) ----------
# **BLUE ACTION — Turn 3**
#
# ACTION: public_affairs_statement
#
# - **Selected action:** public_affairs_statement
#
# - **Reasoning:** Red's disinformation campaign directly targets the information domain, seeking to undermine Blue's legitimacy and sway international opinion. A pre-cleared public affairs statement documenting the lawful nature of Blue's freedom of navigation operation, along with evidence of Red's provocations (e.g., militia deployment), is the most effective countermeasure. This action reinforces Blue's narrative of adherence to international law and transparency, while exposing Red's disinformation efforts.
#
# - **Tradeoffs considered:** Alternatives such as maintaining course and speed (shadow_and_monitor) or deploying a UAV for overwatch (reposition_isr) were considered but do not directly address the information domain challenge posed by Red's disinformation. More aggressive actions, such as active radar sweeps or non-lethal measures, were deemed unnecessary and potentially escalatory given the lack of physical interference.
#
# - **Expected effect:** This action will bolster Blue's credibility in the international arena, countering Red's disinformation and reinforcing the narrative of lawful navigation. It also supports long-term strategic communication goals by documenting Red's behavior and demonstrating Blue's commitment to transparency and international norms.
# ---------- TextMessage (White_Cell) ----------
# **WHITE CELL ADJUDICATION — Turn 3**
#
# **DTG:** T+0014H
#
# **Actions this turn:**
# - Red: **disinformation_release** — Red launches a coordinated disinformation campaign through state-controlled media and social media platforms, accusing Blue of provocative and aggressive actions in the contested waters. The campaign includes fabricated images and narratives designed to portray Red as defending its sovereignty against foreign intrusion.
# - Blue: **public_affairs_statement** — Blue responds with a pre-cleared public affairs statement emphasizing the lawful nature of its freedom of navigation operation. The statement includes evidence of Red's militia deployment and highlights Blue's adherence to international law, countering Red's disinformation with transparency and factual documentation.
#
# **INTERACTION RESOLUTION:**
# Red's disinformation campaign gains some traction in domestic and sympathetic international media but is quickly challenged by Blue's public affairs statement. Blue's release of verifiable evidence, including imagery of Red's militia deployment, undermines the credibility of Red's claims. While the disinformation campaign creates some initial confusion, Blue's proactive communication strategy limits its impact and reinforces its narrative of lawful navigation. The information environment remains contested but tilts slightly in Blue's favor.
#
# **ESCALATION UPDATE:**
# - Previous index: 1
# - Change: [+1] (Red: [+1], Blue: [+0])
# - New index: 2 → **ROUTINE**
#
# **THRESHOLD CROSSING:** NO — The escalation level remains at "ROUTINE," with the primary activity confined to the information domain.
#
# **SITUATIONAL DEVELOPMENTS:**
# - Weather: Conditions remain favorable, with clear skies and calm seas. Visibility continues to support monitoring and documentation efforts.
# - Time of day: Mid-afternoon, with strong sunlight aiding imagery and video capture for both sides.
# - Nearby shipping: No additional civilian vessels detected in the area, reducing the risk of collateral involvement.
# - Media attention: The disinformation campaign and Blue's counterstatement have drawn increased attention from regional and international media outlets. Independent analysts are beginning to scrutinize Red's claims, with some outlets highlighting inconsistencies in the disinformation campaign.
#
# The information domain becomes the primary battleground this turn, with both sides leveraging strategic communication to shape perceptions. Blue's measured and transparent response successfully counters Red's disinformation, maintaining the operational and narrative initiative.
# ---------- TextMessage (StratComm) ----------
# **STRATEGIC COMMUNICATIONS — Turn 3**
#
# **BLUE PUBLIC STATEMENT (DRAFT):**
# "The BNS Resolute continues its lawful freedom of navigation operation in international waters, in full compliance with international law. Recent claims by certain parties attempting to portray this mission as provocative are baseless and contradicted by clear evidence, including the deployment of irregular militia vessels to impede safe passage. We remain committed to transparency and the principles of a free and open maritime domain."
#
# **PREDICTED ADVERSARY RESPONSE:**
# Red will likely double down on its disinformation campaign, amplifying fabricated narratives and selectively releasing misleading or doctored imagery to support its claims. Red state media may accuse Blue of "escalating tensions" by publicizing the militia deployment, framing it as an overreaction. Social media channels aligned with Red may attempt to discredit Blue's evidence by questioning its authenticity or claiming it is staged.
#
# **INFORMATION ENVIRONMENT ASSESSMENT:**
# - Blue narrative strength: **STRONG** — Blue's release of verifiable evidence and adherence to international law strengthens its credibility and undermines Red's disinformation campaign.
# - Red narrative strength: **MODERATE** — While Red's disinformation initially gained traction, its credibility has been eroded by Blue's transparent and factual counter-narrative. However, Red's domestic audience and sympathetic regional actors may still accept its framing.
# - Key narrative battleground: **Credibility and transparency vs. sovereignty defense** — The focus is now on which side can maintain the trust of the international community and demonstrate legitimacy in their actions and claims.
#
# **RECOMMENDATION:**
# Blue should sustain its proactive communication strategy by continuing to release verifiable evidence that highlights Red's provocations and underscores Blue's lawful and professional conduct. Engage with independent analysts and international maritime organizations to validate Blue's claims and further discredit Red's disinformation. Additionally, consider leveraging social media platforms to amplify Blue's narrative, targeting both regional and global audiences to maximize reach and impact.
# <div style='background:#0d1117; color:#c9d1d9; padding:16px; border-radius:8px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><h3 style='color:#58a6ff; margin-top:0;'>Dashboard — Turn 3</h3><table style='border-collapse:collapse; width:100%; color:#c9d1d9;'><tr style='border-bottom:1px solid #30363d;'><th style='padding:4px 8px; text-align:left;'>Side</th><th style='padding:4px 8px;'>Impact</th><th style='padding:4px 8px;'>Escalation</th><th style='padding:4px 8px;'>Communication</th><th style='padding:4px 8px;'>Political</th><th style='padding:4px 8px;'>Resource</th></tr><tr style='background:#0d1b2a;'><td style='padding:4px 8px; font-weight:bold;'>BLUE (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+4</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+6</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+4</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td></tr><tr style='background:#1a0d0d;'><td style='padding:4px 8px; font-weight:bold;'>RED (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+4</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td></tr></table><div style='margin-top:12px; padding:8px; border-radius:4px; background:#2ea04322; border:1px solid #2ea043;'><b>ESCALATION:</b> 1 — <b>ROUTINE</b> &nbsp;|&nbsp; <b>ROE:</b> PEACETIME</div></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Escalation index:</span> <span style='color: #f0f6fc; font-weight: 600;'>1</span></div>
# <div style='background:#1a1a2e; color:#8b949e; padding:6px 12px; margin:12px 0; border-left:3px solid #da3633; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size:11px;'>Escalation building — advancing to Turn 4...</div>
# <div style='background:#1a1a2e; color:#e0e0ff; padding:12px; border-radius:6px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><b>=== TURN 4 — T+0014H ===</b><br>Escalation: 1 (ROUTINE) | ROE: PEACETIME</div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Team</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>Running round-robin wargame turn</span></div>
# ---------- TextMessage (user) ----------
# === WARGAME TURN 4 — T+0014H ===
#
# CURRENT GAME STATE:
# {
#   "synthetic": true,
#   "disclaimer": "All data is artificially generated for research and educational purposes only.",
#   "meta": {
#     "scenario": "Cerulean Sea \u2014 Fictitious Archipelago Standoff (SYNTHETIC)",
#     "turn": 4,
#     "dtg": "T+0014H",
#     "roe_posture": "PEACETIME"
#   },
#   "blue": {
#     "unit": "BNS Resolute (DDG-X1) [FICTIONAL]",
#     "position": "Grid AA-17",
#     "mission": "Demonstrate freedom of navigation through contested waters",
#     "cumulative_scores": {
#       "impact": 4,
#       "escalation": -1,
#       "communication": 6,
#       "political": 4,
#       "resource": 0
#     }
#   },
#   "red": {
#     "unit": "RFS Sentinel + Militia Flotilla [FICTIONAL]",
#     "position": "Grid AB-14",
#     "mission": "Deny access; assert territorial claims",
#     "cumulative_scores": {
#       "impact": 3,
#       "escalation": 0,
#       "communication": 4,
#       "political": 3,
#       "resource": -1
#     }
#   },
#   "escalation_index": 1,
#   "escalation_level": "ROUTINE",
#   "turn_log": []
# }
#
# TURN SEQUENCE:
# 1. Red Team — select and execute one provocation
# 2. Legal/ROE — assess which Blue actions are authorized given current ROE and escalation
# 3. Blue Planner — select and execute one response (must respect Legal constraints)
# 4. White Cell — adjudicate the interaction, update escalation index
# 5. StratComm — draft Blue public statement and assess information environment
# 6. Explainability — produce a transparent reasoning trace and bias check for this turn
#
# Each agent: perform your role now. Reference the current escalation index (1),
# escalation level (ROUTINE), and ROE posture (PEACETIME).
# ---------- TextMessage (Red_Team) ----------
# ACTION: ais_spoofing
#
# **RED ACTION — Turn 4**
#
# - **Selected action:** ais_spoofing
#
# - **Reasoning:** With Blue continuing to gain momentum in communication and political domains, Red needs to disrupt Blue's operational picture without escalating the situation. Spoofing AIS (Automatic Identification System) signals to broadcast false vessel identities or positions introduces confusion into Blue's situational awareness. This action is subtle, non-kinetic, and deniable, making it appropriate for the current "ROUTINE" escalation level under peacetime ROE.
#
# - **Intended effect:** Red aims to degrade Blue's ability to maintain a clear operational picture, potentially causing delays or missteps in its freedom of navigation mission. This also serves as a signal of Red's technological capability and willingness to contest Blue's presence in the contested waters.
#
# - **Risk accepted:** If Blue detects the spoofing and attributes it to Red, it could lead to reputational damage or bolster Blue's justification for its mission. Additionally, this action may have limited immediate impact on Blue's operations if they quickly identify and mitigate the spoofing.
# ---------- TextMessage (Legal_ROE) ----------
# **LEGAL/ROE ASSESSMENT — Turn 4**
#
# **Current ROE:** PEACETIME
# **Escalation:** 1 (ROUTINE)
#
# | Blue Action                        | Legal Status  | Rationale                                                                 |
# |------------------------------------|---------------|---------------------------------------------------------------------------|
# | Maintain course and speed          | AUTHORIZED    | Consistent with freedom of navigation rights under international law.    |
# | Conduct active radar sweeps        | AUTHORIZED    | Defensive measure; does not constitute a use of force.                   |
# | Issue radio challenge to Red units | AUTHORIZED    | Non-escalatory communication to clarify intent and assert navigation.    |
# | Deploy small UAV for overwatch     | AUTHORIZED    | Defensive surveillance in response to potential electronic interference. |
# | Alter course to avoid Red units    | RESTRICTED    | Legal but may undermine freedom of navigation assertion.                 |
# | Conduct live-fire gunnery exercise | PROHIBITED    | Inconsistent with peacetime ROE; no hostile act/intent detected.         |
# | Use non-lethal means (e.g., LRAD)  | RESTRICTED    | Legal but could escalate tensions; requires clear justification.         |
# | Investigate AIS anomalies          | AUTHORIZED    | Defensive action to restore situational awareness; non-escalatory.       |
#
# **ROE CHANGE RECOMMENDATION:** NO — AIS spoofing, while disruptive, does not meet the threshold of a hostile act or hostile intent under international law.
#
# **KEY LEGAL CONSIDERATIONS:**
# - AIS spoofing is a form of electronic interference that complicates navigation but does not constitute a direct threat to Blue's vessel or personnel. It remains below the threshold for a change in ROE.
# - Blue should focus on documenting and mitigating the spoofing while maintaining its operational objectives. Attribution of the spoofing to Red must be handled carefully to avoid premature escalation.
# ---------- TextMessage (Blue_Planner) ----------
# **BLUE ACTION — Turn 4**
#
# ACTION: reposition_isr
#
# - **Selected action:** reposition_isr
#
# - **Reasoning:** Red's AIS spoofing introduces potential confusion into Blue's situational awareness, which could jeopardize the freedom of navigation mission. Redirecting ISR assets, such as patrol aircraft or UAVs, to obtain better coverage of the area will help Blue verify vessel identities and positions, mitigating the effects of the spoofing. This action is defensive, non-escalatory, and ensures Blue maintains operational control.
#
# - **Tradeoffs considered:** Maintaining course and speed (shadow_and_monitor) was considered but does not address the immediate need to counter the spoofing. Investigating AIS anomalies was also an option but would be less effective without enhanced ISR coverage. More aggressive actions, such as active radar sweeps or non-lethal measures, were rejected as unnecessary escalations given the current low threat level.
#
# - **Expected effect:** This action will restore Blue's situational awareness, enabling the BNS Resolute to continue its mission with confidence. It also demonstrates Blue's technological capability and resolve to counter Red's interference, reinforcing Blue's operational and strategic objectives.
# ---------- TextMessage (White_Cell) ----------
# **WHITE CELL ADJUDICATION — Turn 4**
#
# **DTG:** T+0016H
#
# **Actions this turn:**
# - Red: **ais_spoofing** — Red initiates AIS spoofing, broadcasting false signals that create phantom vessels and misrepresent the positions of real vessels in the contested waters. This action aims to degrade Blue's situational awareness and complicate its operational picture.
# - Blue: **reposition_isr** — Blue redirects ISR assets, including a UAV and a maritime patrol aircraft, to enhance coverage of the area. These assets focus on verifying vessel identities and positions, countering the effects of the AIS spoofing and restoring situational awareness.
#
# **INTERACTION RESOLUTION:**
# Red's AIS spoofing initially creates confusion in Blue's operational picture, with phantom vessels appearing on navigational displays. However, Blue's repositioned ISR assets quickly identify the spoofing activity and confirm the actual positions of vessels in the area. The spoofing is mitigated before it can significantly impact Blue's freedom of navigation mission. While Red demonstrates its electronic warfare capabilities, Blue's prompt response reinforces its operational control and technological resilience.
#
# **ESCALATION UPDATE:**
# - Previous index: 2
# - Change: [+1] (Red: [+1], Blue: [+0])
# - New index: 3 → **PROVOCATION**
#
# **THRESHOLD CROSSING:** YES — The escalation index crosses into **PROVOCATION** (Level 2). This marks a shift in the situation, as Red's AIS spoofing represents a more deliberate effort to interfere with Blue's operations, prompting a more active response from Blue.
#
# **SITUATIONAL DEVELOPMENTS:**
# - Weather: Conditions remain stable, with clear skies and calm seas. Visibility supports ISR operations and vessel identification.
# - Time of day: Late afternoon, with sufficient daylight for ISR assets to operate effectively.
# - Nearby shipping: A small fishing vessel enters the area, but its AIS signal matches its observed position, confirming it is not part of the spoofing activity.
# - Media attention: Reports of electronic interference in the contested waters begin to circulate in regional media, with speculation about Red's involvement. Blue's ISR response is not publicly disclosed but is documented for potential future use in strategic communications.
#
# The escalation to "PROVOCATION" reflects the increasing complexity of the situation, as Red's actions shift from passive monitoring to active interference. Blue's measured and effective response maintains operational momentum while avoiding unnecessary escalation.
# ---------- TextMessage (StratComm) ----------
# **STRATEGIC COMMUNICATIONS — Turn 4**
#
# **BLUE PUBLIC STATEMENT (DRAFT):**
# "The BNS Resolute continues its lawful freedom of navigation operation in international waters, despite attempts to disrupt maritime safety through electronic interference. We remain committed to transparency and upholding international law, ensuring the free and open use of the seas for all nations."
#
# **PREDICTED ADVERSARY RESPONSE:**
# Red is likely to deny involvement in the AIS spoofing and may accuse Blue of fabricating claims to justify its presence in contested waters. Red state media could frame the spoofing reports as "unsubstantiated allegations" and shift focus to portraying Blue's ISR activities as intrusive or escalatory. Social media narratives may attempt to downplay the spoofing or redirect attention to unrelated issues, such as historical grievances or broader geopolitical tensions.
#
# **INFORMATION ENVIRONMENT ASSESSMENT:**
# - Blue narrative strength: **STRONG** — Blue's prompt and effective response to the spoofing reinforces its credibility and operational competence. The emphasis on transparency and adherence to international law continues to resonate with international audiences.
# - Red narrative strength: **MODERATE** — While Red's AIS spoofing demonstrates technological capability, its deniability limits its ability to leverage the action in the information domain. The lack of credible counter-narratives weakens its position.
# - Key narrative battleground: **Maritime safety and operational legitimacy** — The focus is on whether Red's actions undermine maritime safety and whether Blue's response is proportionate and justified.
#
# **RECOMMENDATION:**
# Blue should prepare to release evidence of the AIS spoofing, such as radar data or ISR imagery, to further discredit Red's actions and reinforce its narrative of transparency and professionalism. Engage with international maritime organizations to highlight the risks posed by electronic interference to global shipping and maritime safety. This approach not only counters Red's denials but also broadens the narrative to emphasize the importance of maintaining a rules-based maritime order.
# <div style='background:#0d1117; color:#c9d1d9; padding:16px; border-radius:8px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><h3 style='color:#58a6ff; margin-top:0;'>Dashboard — Turn 4</h3><table style='border-collapse:collapse; width:100%; color:#c9d1d9;'><tr style='border-bottom:1px solid #30363d;'><th style='padding:4px 8px; text-align:left;'>Side</th><th style='padding:4px 8px;'>Impact</th><th style='padding:4px 8px;'>Escalation</th><th style='padding:4px 8px;'>Communication</th><th style='padding:4px 8px;'>Political</th><th style='padding:4px 8px;'>Resource</th></tr><tr style='background:#0d1b2a;'><td style='padding:4px 8px; font-weight:bold;'>BLUE (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+6</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+6</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+4</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td></tr><tr style='background:#1a0d0d;'><td style='padding:4px 8px; font-weight:bold;'>RED (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+4</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+1</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+6</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td></tr></table><div style='margin-top:12px; padding:8px; border-radius:4px; background:#2ea04322; border:1px solid #2ea043;'><b>ESCALATION:</b> 2 — <b>ROUTINE</b> &nbsp;|&nbsp; <b>ROE:</b> PEACETIME</div></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Escalation index:</span> <span style='color: #f0f6fc; font-weight: 600;'>2</span></div>
# <div style='background:#0d1117; color:#c9d1d9; padding:16px; border-radius:8px; margin:16px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><h3 style='color:#58a6ff; margin-top:0;'>Encounter Summary — 4 Turns</h3><table style='border-collapse:collapse; width:100%; color:#c9d1d9;'><tr style='border-bottom:1px solid #30363d;'><th>Turn</th><th>DTG</th><th>Red Action</th><th>Blue Action</th><th>Esc Δ</th><th>Index</th><th>Level</th></tr><tr><td>1</td><td>T+0008H</td><td>Shadow & Observe (Low Profile)</td><td>Shadow & Monitor</td><td>-2</td><td>0</td><td style='color:#2ea043;'>ROUTINE</td></tr><tr><td>2</td><td>T+0010H</td><td>Deploy Maritime Militia Swarm</td><td>Hail & Warn (Bridge-to-Bridge)</td><td>+1</td><td>1</td><td style='color:#2ea043;'>ROUTINE</td></tr><tr><td>3</td><td>T+0012H</td><td>Disinformation Release</td><td>Issue Public Affairs Statement</td><td>+0</td><td>1</td><td style='color:#2ea043;'>ROUTINE</td></tr><tr><td>4</td><td>T+0014H</td><td>AIS Spoofing</td><td>Reposition ISR Assets</td><td>+1</td><td>2</td><td style='color:#2ea043;'>ROUTINE</td></tr></table></div>

# %% [markdown]
# ## Human-in-the-Loop — Commander Override
#
# The commander can override Blue's action selection for any turn. Edit `commander_action` below and run the cell to play Turn 5 with a forced Blue action.
#
# **Available Blue actions:** `shadow_and_monitor`, `hail_and_warn`, `reposition_isr`, `close_to_visual`, `emcon_alpha`, `active_sonar`, `public_affairs_statement`, `request_reinforcements`, `withdraw_to_deescalate`

# %%
# ═══════════════════════════════════════════════════════════════
# COMMANDER OVERRIDE — Edit this action, then run the cell.
# Set to None to let the Blue agent decide autonomously.
# ═══════════════════════════════════════════════════════════════

commander_action = "withdraw_to_deescalate"  # Try: "active_sonar", "public_affairs_statement", etc.

render_commander_box(
    f"Blue will execute **{commander_action}** this turn.",
    label="COMMANDER ORDERS",
)

turn_5 = await run_turn(5, blue_override=commander_action)
# Out:
# <div style='background:#1a2a1a; color:#b0ffb0; padding:12px; border-radius:6px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><b>COMMANDER ORDERS:</b> Blue will execute **withdraw_to_deescalate** this turn.</div>
# <div style='background:#1a1a2e; color:#e0e0ff; padding:12px; border-radius:6px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><b>=== TURN 5 — T+0016H ===</b><br>Escalation: 2 (ROUTINE) | ROE: PEACETIME<br><b style='color:#ffb0b0;'>COMMANDER OVERRIDE: withdraw_to_deescalate</b></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #58a6ff; font-weight: 600;'>Team</span><span style='color: #6e7781;'> → </span><span style='color: #c9d1d9;'>Running round-robin wargame turn</span></div>
# ---------- TextMessage (user) ----------
# === WARGAME TURN 5 — T+0016H ===
#
# CURRENT GAME STATE:
# {
#   "synthetic": true,
#   "disclaimer": "All data is artificially generated for research and educational purposes only.",
#   "meta": {
#     "scenario": "Cerulean Sea \u2014 Fictitious Archipelago Standoff (SYNTHETIC)",
#     "turn": 5,
#     "dtg": "T+0016H",
#     "roe_posture": "PEACETIME"
#   },
#   "blue": {
#     "unit": "BNS Resolute (DDG-X1) [FICTIONAL]",
#     "position": "Grid AA-17",
#     "mission": "Demonstrate freedom of navigation through contested waters",
#     "cumulative_scores": {
#       "impact": 6,
#       "escalation": -1,
#       "communication": 6,
#       "political": 4,
#       "resource": -1
#     }
#   },
#   "red": {
#     "unit": "RFS Sentinel + Militia Flotilla [FICTIONAL]",
#     "position": "Grid AB-14",
#     "mission": "Deny access; assert territorial claims",
#     "cumulative_scores": {
#       "impact": 4,
#       "escalation": 1,
#       "communication": 6,
#       "political": 3,
#       "resource": -1
#     }
#   },
#   "escalation_index": 2,
#   "escalation_level": "ROUTINE",
#   "turn_log": []
# }
#
# TURN SEQUENCE:
# 1. Red Team — select and execute one provocation
# 2. Legal/ROE — assess which Blue actions are authorized given current ROE and escalation
# 3. Blue Planner — select and execute one response (must respect Legal constraints; COMMANDER OVERRIDE: Blue MUST select 'withdraw_to_deescalate')
# 4. White Cell — adjudicate the interaction, update escalation index
# 5. StratComm — draft Blue public statement and assess information environment
# 6. Explainability — produce a transparent reasoning trace and bias check for this turn
#
# Each agent: perform your role now. Reference the current escalation index (2),
# escalation level (ROUTINE), and ROE posture (PEACETIME).
# ---------- TextMessage (Red_Team) ----------
# ACTION: unsafe_intercept
#
# **RED ACTION — Turn 5**
#
# - **Selected action:** unsafe_intercept
#
# - **Reasoning:** With the escalation index rising to 2 and Blue's cumulative impact score significantly outpacing Red's, it is necessary to take a more assertive action to challenge Blue's operational freedom. Conducting an unsafe intercept, closing to a dangerously close point of approach (CPA < 100 yards), signals Red's resolve to deny access and assert territorial claims. This action is provocative but stops short of outright aggression, remaining within the bounds of peacetime ROE.
#
# - **Intended effect:** Red aims to force Blue into a defensive posture, potentially disrupting its mission and creating an opportunity for Blue to reconsider its course of action. This also serves as a strong signal to domestic and international audiences of Red's commitment to defending its claimed waters.
#
# - **Risk accepted:** There is a significant risk of miscalculation or collision, which could escalate the situation beyond Red's intent. Additionally, this action may provide Blue with justification for stronger responses, including public condemnation or operational countermeasures.
# ---------- TextMessage (Legal_ROE) ----------
# **LEGAL/ROE ASSESSMENT — Turn 5**
#
# **Current ROE:** PEACETIME
# **Escalation:** 2 (ROUTINE)
#
# | Blue Action                        | Legal Status  | Rationale                                                                 |
# |------------------------------------|---------------|---------------------------------------------------------------------------|
# | Maintain course and speed          | AUTHORIZED    | Consistent with freedom of navigation rights under international law.    |
# | Conduct active radar sweeps        | AUTHORIZED    | Defensive measure; does not constitute a use of force.                   |
# | Issue radio challenge to Red units | AUTHORIZED    | Non-escalatory communication to clarify intent and assert navigation.    |
# | Deploy small UAV for overwatch     | AUTHORIZED    | Defensive surveillance in response to unsafe intercept.                  |
# | Alter course to avoid Red units    | RESTRICTED    | Legal but may undermine freedom of navigation assertion.                 |
# | Conduct live-fire gunnery exercise | PROHIBITED    | Inconsistent with peacetime ROE; no hostile act/intent detected.         |
# | Use non-lethal means (e.g., LRAD)  | RESTRICTED    | Legal but could escalate tensions; requires clear justification.         |
# | Withdraw to de-escalate            | AUTHORIZED    | Aligns with commander override and avoids further escalation.            |
#
# **ROE CHANGE RECOMMENDATION:** NO — While the unsafe intercept is provocative and increases the risk of collision, it does not meet the threshold of a hostile act or hostile intent under international law.
#
# **KEY LEGAL CONSIDERATIONS:**
# - Unsafe intercepts violate navigational safety norms under COLREGS (International Regulations for Preventing Collisions at Sea) but do not justify a shift in ROE unless they result in a direct threat to Blue's vessel or personnel.
# - Blue's mandated withdrawal to de-escalate is legally sound and strategically prudent, as it avoids unnecessary escalation while documenting Red's unsafe actions for future diplomatic leverage.
# ---------- TextMessage (Blue_Planner) ----------
# **BLUE ACTION — Turn 5**
#
# ACTION: withdraw_to_deescalate
#
# - **Selected action:** withdraw_to_deescalate
#
# - **Reasoning:** The commander’s override mandates a controlled withdrawal to de-escalate the situation. Red's unsafe intercept significantly increases the risk of collision or miscalculation, making this action the safest and most prudent response. By withdrawing while maintaining surveillance, Blue signals non-aggression and avoids further escalation, consistent with peacetime ROE and international law.
#
# - **Tradeoffs considered:** While maintaining course and speed or issuing a radio challenge could assert Blue's navigational rights, these actions risk further escalation given the unsafe proximity of Red's vessels. Deploying a UAV for overwatch was considered but would not directly address the immediate risk posed by the unsafe intercept. More aggressive actions, such as active radar sweeps or non-lethal measures, were rejected as unnecessarily provocative under the current circumstances.
#
# - **Expected effect:** This action will reduce the immediate risk of collision and demonstrate Blue's commitment to de-escalation while documenting Red's unsafe behavior for future use in strategic communications and legal forums. It preserves Blue's credibility as a responsible actor in the contested waters.
# ---------- TextMessage (White_Cell) ----------
# **WHITE CELL ADJUDICATION — Turn 5**
#
# **DTG:** T+0018H
#
# **Actions this turn:**
# - Red: **unsafe_intercept** — Red conducts an unsafe intercept, closing to within 100 yards of BNS Resolute. The maneuver is aggressive and creates a high-risk situation, forcing Blue to take immediate action to avoid a potential collision.
# - Blue: **withdraw_to_deescalate** — In response to the unsafe intercept, BNS Resolute executes a controlled withdrawal from the immediate area, maintaining surveillance and documenting Red's actions while avoiding further escalation.
#
# **INTERACTION RESOLUTION:**
# Red's unsafe intercept creates a tense and dangerous situation, with the potential for miscalculation or collision. Blue's decision to withdraw reduces the immediate risk and avoids a direct confrontation. The withdrawal is executed in a deliberate and professional manner, ensuring that Blue maintains situational awareness and collects evidence of Red's provocative behavior. Red achieves a temporary tactical advantage by asserting dominance in the contested waters, but Blue's measured response preserves its strategic credibility and avoids unnecessary escalation.
#
# **ESCALATION UPDATE:**
# - Previous index: 3
# - Change: [+2] (Red: [+2], Blue: [+0])
# - New index: 5 → **CONFRONTATION**
#
# **THRESHOLD CROSSING:** YES — The escalation index crosses into **CONFRONTATION** (Level 3). This reflects the significant increase in tension and risk resulting from Red's unsafe intercept and the need for Blue to take active measures to de-escalate.
#
# **SITUATIONAL DEVELOPMENTS:**
# - Weather: Conditions remain favorable, with clear skies and calm seas. Visibility supports surveillance and documentation efforts.
# - Time of day: Early evening, with sufficient light for visual monitoring but approaching dusk.
# - Nearby shipping: No additional civilian vessels detected in the area, minimizing the risk of collateral involvement.
# - Media attention: Reports of the unsafe intercept begin to surface in regional media, with speculation about the potential for escalation. Blue's withdrawal is not immediately publicized but is documented for potential use in strategic communications.
#
# The escalation to "CONFRONTATION" marks a critical juncture in the standoff, with Red's actions pushing the situation toward a more dangerous and unpredictable phase. Blue's controlled withdrawal mitigates the immediate risk while preserving its ability to respond strategically in the information and diplomatic domains.
# ---------- TextMessage (StratComm) ----------
# **STRATEGIC COMMUNICATIONS — Turn 5**
#
# **BLUE PUBLIC STATEMENT (DRAFT):**
# "The BNS Resolute has completed its freedom of navigation operation in accordance with international law, despite unsafe and provocative actions by other parties in the region. These reckless maneuvers endangered maritime safety and violated established norms of conduct at sea. We remain committed to upholding the principles of a free and open maritime domain and will continue to document and address such actions through appropriate channels."
#
# **PREDICTED ADVERSARY RESPONSE:**
# Red will likely frame Blue's withdrawal as a victory, portraying it as a retreat in the face of Red's resolve to defend its territorial claims. State media may emphasize Red's "firm but measured" actions, downplaying the unsafe intercept while highlighting Blue's departure as evidence of its inability to challenge Red's dominance. Social media narratives may amplify this framing, with claims of Red's sovereignty being upheld against foreign interference.
#
# **INFORMATION ENVIRONMENT ASSESSMENT:**
# - Blue narrative strength: **MODERATE** — Blue's emphasis on professionalism, adherence to international law, and documentation of Red's unsafe actions bolsters its credibility, but the withdrawal may be perceived as a loss of momentum or resolve by some audiences.
# - Red narrative strength: **STRONG** — Red's ability to frame Blue's withdrawal as a tactical victory resonates with domestic and sympathetic regional audiences, reinforcing its narrative of territorial defense.
# - Key narrative battleground: **Perception of strength vs. adherence to norms** — The focus is on whether Blue's withdrawal is seen as a responsible de-escalation or a concession, and whether Red's actions are viewed as assertive or reckless.
#
# **RECOMMENDATION:**
# Blue should immediately release evidence of Red's unsafe intercept, such as video footage or radar data, to highlight the reckless and provocative nature of Red's actions. Frame the withdrawal as a calculated and responsible decision to prioritize maritime safety and de-escalation, underscoring Blue's commitment to international norms. Engage with international maritime organizations and allied nations to amplify this narrative and call for accountability for Red's behavior. This approach shifts the focus from tactical outcomes to strategic principles, reinforcing Blue's long-term objectives in the region.
# <div style='background:#0d1117; color:#c9d1d9; padding:16px; border-radius:8px; margin:8px 0; font-family:ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace;'><h3 style='color:#58a6ff; margin-top:0;'>Dashboard — Turn 5</h3><table style='border-collapse:collapse; width:100%; color:#c9d1d9;'><tr style='border-bottom:1px solid #30363d;'><th style='padding:4px 8px; text-align:left;'>Side</th><th style='padding:4px 8px;'>Impact</th><th style='padding:4px 8px;'>Escalation</th><th style='padding:4px 8px;'>Communication</th><th style='padding:4px 8px;'>Political</th><th style='padding:4px 8px;'>Resource</th></tr><tr style='background:#0d1b2a;'><td style='padding:4px 8px; font-weight:bold;'>BLUE (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+5</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+7</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#8b949e;'>+0</span></td></tr><tr style='background:#1a0d0d;'><td style='padding:4px 8px; font-weight:bold;'>RED (cumulative)</td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+6</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+3</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+5</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#2ea043;'>+2</span></td><td style='padding:4px 8px; text-align:center;'><span style='color:#da3633;'>-1</span></td></tr></table><div style='margin-top:12px; padding:8px; border-radius:4px; background:#2ea04322; border:1px solid #2ea043;'><b>ESCALATION:</b> 2 — <b>ROUTINE</b> &nbsp;|&nbsp; <b>ROE:</b> PEACETIME</div></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Escalation index:</span> <span style='color: #f0f6fc; font-weight: 600;'>2</span></div>

# %% [markdown]
# ## Export Game Log for Demo 5 (AAR)
#
# Save the full game log as JSON. This file is the direct input to Demo 5's After-Action Review agents.
#
# ### Azure Considerations for Data Persistence
#
# In a production or team-collaboration scenario, you would typically save artifacts like this game log to an Azure storage service rather than a local file:
#
# | Service | Use Case | Learn More |
# |---|---|---|
# | **[Azure Blob Storage](https://learn.microsoft.com/azure/storage/blobs/storage-blobs-overview)** | Store large, unstructured data (files, logs, media). Ideal for persisting game logs, model outputs, and evaluation results. | [Quickstart: Upload and download blobs](https://learn.microsoft.com/azure/storage/blobs/storage-quickstart-blobs-python) |
# | **[Azure Cosmos DB](https://learn.microsoft.com/azure/cosmos-db/introduction)** | Globally distributed NoSQL database. Good for structured game-state data that multiple services need to query in real time. | [Quickstart: Azure Cosmos DB for NoSQL](https://learn.microsoft.com/azure/cosmos-db/nosql/quickstart-python) |
# | **[Azure AI Foundry Projects](https://learn.microsoft.com/azure/ai-foundry/how-to/create-projects)** | Organize models, datasets, evaluations, and artifacts within a project workspace. Tracing and evaluation logs can be stored here automatically. | [Manage project resources](https://learn.microsoft.com/azure/ai-foundry/how-to/create-projects) |
#
# For this demo, we export to a local JSON file for simplicity and portability.

# %%
# ── Export game log ────────────────────────────────────────────
export_log = {
    "scenario": game_state["meta"]["scenario"],
    "total_turns": len(game_log),
    "final_escalation": {
        "index": game_state["escalation_index"],
        "level": game_state["escalation_level"],
    },
    "final_roe": game_state["meta"]["roe_posture"],
    "blue_cumulative": game_state["blue"]["cumulative_scores"],
    "red_cumulative": game_state["red"]["cumulative_scores"],
    "turns": [
        {
            "turn": t["turn"],
            "dtg": t["dtg"],
            "red_action": t["red_action"]["key"],
            "red_label": t["red_action"]["label"],
            "blue_action": t["blue_action"]["key"],
            "blue_label": t["blue_action"]["label"],
            "escalation_delta": t["escalation_delta"],
            "escalation_index": t["escalation_index"],
            "escalation_level": t["escalation_level"],
            "threshold_crossing": t["threshold_crossing"],
            "roe_posture": t["roe_posture"],
            "agent_messages": t["agent_messages"],
        }
        for t in game_log
    ],
}

log_path = DEMO2_LOG_FILENAME
with open(log_path, "w") as f:
    json.dump(export_log, f, indent=2)

log_success(f"Game log exported to: {log_path}")
log_metric("Turns", len(game_log))
log_metric("Final escalation", f"{game_state['escalation_index']} ({game_state['escalation_level']})")
log_metric("Final ROE", game_state["meta"]["roe_posture"])
log_info("Feed this file into Demo 5 (AAR) for after-action analysis.")
# Out:
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #2ea043; font-weight: 600;'>[SUCCESS]</span> <span style='color: #24292f;'>[2026-02-21 04:34:14]</span> <span style='color: #24292f;'>Game log exported to: demo2_game_log.json</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Turns:</span> <span style='color: #f0f6fc; font-weight: 600;'>5</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Final escalation:</span> <span style='color: #f0f6fc; font-weight: 600;'>2 (ROUTINE)</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px; padding: 2px 0;'><span style='color: #d2a8ff; font-weight: 600;'>[METRIC]</span> <span style='color: #c9d1d9;'>Final ROE:</span> <span style='color: #f0f6fc; font-weight: 600;'>PEACETIME</span></div>
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #1f6feb; font-weight: 600;'>[INFO]</span> <span style='color: #24292f;'>[2026-02-21 04:34:14]</span> <span style='color: #24292f;'>Feed this file into Demo 5 (AAR) for after-action analysis.</span></div>
# LogEntry(level='INFO', message='Feed this file into Demo 5 (AAR) for after-action analysis.', timestamp='2026-02-21 04:34:14', extra={})

# %% [markdown]
# ## Reset / Cleanup
#
# Clear all runtime state to re-run the encounter from scratch.

# %%
# Reset game state
game_state["meta"]["turn"] = 0
game_state["meta"]["dtg"] = "T+0000H"
game_state["meta"]["roe_posture"] = ROEPosture.PEACETIME.value
game_state["escalation_index"] = 0
game_state["escalation_level"] = EscalationLevel.ROUTINE.value
game_state["turn_log"] = []
for side in ["blue", "red"]:
    for dim in SCORING_DIMENSIONS:
        game_state[side]["cumulative_scores"][dim] = 0

# Clear history
game_log.clear()
all_messages.clear()
clear_logs()

# Reset agents
from autogen_core import CancellationToken
for agent in all_agents:
    await agent.on_reset(CancellationToken())

log_success("Game state cleared. Ready to re-run from Turn 1.")
# Out:
# <div style='font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; font-size: 12px;'><span style='color: #2ea043; font-weight: 600;'>[SUCCESS]</span> <span style='color: #24292f;'>[2026-02-21 04:35:50]</span> <span style='color: #24292f;'>Game state cleared. Ready to re-run from Turn 1.</span></div>
# LogEntry(level='SUCCESS', message='Game state cleared. Ready to re-run from Turn 1.', timestamp='2026-02-21 04:35:50', extra={})
